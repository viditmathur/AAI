# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # January

# %% [markdown]
# ## Aircraft All India International and Domestic

# %%
jan_aircraft = pd.read_csv("/Users/kushalgupta/Downloads/Main/1. Jan/Comma Delimited/Aircraft/All India.csv")
jan_aircraft = jan_aircraft.iloc[0:10,:]
jan_aircraft.columns = ["year","international","domestic","total"]
X_jan = jan_aircraft["year"].values.reshape(-1,1)
Y_jan_aircraft_international = jan_aircraft["international"]
alg_jan_aircraft_international = LinearRegression()
alg_jan_aircraft_international.fit(X_jan,Y_jan_aircraft_international)

Y_jan_aircraft_domestic = jan_aircraft["domestic"]
alg_jan_aircraft_domestic = LinearRegression()
alg_jan_aircraft_domestic.fit(X_jan,Y_jan_aircraft_domestic)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
predictions = alg_jan_aircraft_international.predict([[2019],[2020], [2021]])
print("Prediction for 2019 -" , end = " ")
print(int(predictions[0]))
print("Prediction for 2020 -" , end = " ")
print(int(predictions[1]))
print("Prediction for 2021 -" , end = " ")
print(int(predictions[2]))
# Out:
# Prediction for 2019 - 38247
# Prediction for 2020 - 39823
# Prediction for 2021 - 41399

# %%
plt.scatter(X_jan,Y_jan_aircraft_international)
plt.scatter([2019,2020,2021], predictions, marker = "^")
plt.title("All India International")
plt.ylabel("Aircrafts")
plt.xlabel("Year")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
predictions = alg_jan_aircraft_domestic.predict([[2019],[2020], [2021]])
print("Prediction for 2019 -" , end = " ")
print(int(predictions[0]))
print("Prediction for 2020 -" , end = " ")
print(int(predictions[1]))
print("Prediction for 2021 -" , end = " ")
print(int(predictions[2]))
# Out:
# Prediction for 2019 - 154515
# Prediction for 2020 - 162294
# Prediction for 2021 - 170074

# %%
plt.scatter(X_jan,Y_jan_aircraft_domestic)
plt.scatter([2019,2020,2021], predictions, marker = "^")


plt.title("All India Domestic")
plt.ylabel("Aircrafts")
plt.xlabel("Year")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %% [markdown]
# ## Aircraft Delhi International and Domestic

# %%
jan_aircraft_delhi = pd.read_csv("/Users/kushalgupta/Downloads/Main/1. Jan/Comma Delimited/Aircraft/Delhi.csv")
jan_aircraft_delhi = jan_aircraft_delhi.iloc[0:10,:]
jan_aircraft_delhi.columns = ["year","international","domestic","total"]
X_jan = jan_aircraft_delhi["year"].values.reshape(-1,1)
Y_jan_aircraft_international_delhi = jan_aircraft_delhi["international"]
alg_jan_aircraft_international_delhi = LinearRegression()
alg_jan_aircraft_international_delhi.fit(X_jan,Y_jan_aircraft_international_delhi)

Y_jan_aircraft_domestic_delhi = jan_aircraft_delhi["domestic"]
alg_jan_aircraft_domestic_delhi = LinearRegression()
alg_jan_aircraft_domestic_delhi.fit(X_jan,Y_jan_aircraft_domestic_delhi)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
predictions = alg_jan_aircraft_international_delhi.predict([[2019],[2020], [2021]])
print("Prediction for 2019 -" , end = " ")
print(int(predictions[0]))
print("Prediction for 2020 -" , end = " ")
print(int(predictions[1]))
print("Prediction for 2021 -" , end = " ")
print(int(predictions[2]))
# Out:
# Prediction for 2019 - 9570
# Prediction for 2020 - 10015
# Prediction for 2021 - 10460

# %%
plt.scatter(X_jan,Y_jan_aircraft_international_delhi)
plt.scatter([2019,2020,2021], predictions, marker = "^")


plt.title("Delhi International")
plt.ylabel("Aircrafts")
plt.xlabel("Year")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
predictions = alg_jan_aircraft_domestic_delhi.predict([[2019],[2020], [2021]])
print("Prediction for 2019 -" , end = " ")
print(int(predictions[0]))
print("Prediction for 2020 -" , end = " ")
print(int(predictions[1]))
print("Prediction for 2021 -" , end = " ")
print(int(predictions[2]))
# Out:
# Prediction for 2019 - 26642
# Prediction for 2020 - 28120
# Prediction for 2021 - 29597

# %%
plt.scatter(X_jan,Y_jan_aircraft_domestic_delhi)
plt.scatter([2019,2020,2021], predictions, marker = "^")


plt.title("Delhi Domestic")
plt.ylabel("Aircrafts")
plt.xlabel("Year")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %% [markdown]
# ## Freight All India International and Domestic

# %%
jan_freight = pd.read_csv("/Users/kushalgupta/Downloads/Main/1. Jan/Comma Delimited/Freight/All India.csv")
jan_freight = jan_freight.iloc[0:10,:]
jan_freight.columns = ["year","international","domestic","total"]
X_jan = jan_freight["year"].values.reshape(-1,1)
Y_jan_freight_international = jan_freight["international"]
alg_jan_freight_international = LinearRegression()
alg_jan_freight_international.fit(X_jan,Y_jan_freight_international)

Y_jan_freight_domestic = jan_aircraft["domestic"]
alg_jan_freight_domestic = LinearRegression()
alg_jan_freight_domestic.fit(X_jan,Y_jan_freight_domestic)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
predictions = alg_jan_freight_international.predict([[2019],[2020], [2021]])
print("Prediction for 2019 -" , end = " ")
print(int(predictions[0]))
print("Prediction for 2020 -" , end = " ")
print(int(predictions[1]))
print("Prediction for 2021 -" , end = " ")
print(int(predictions[2]))
# Out:
# Prediction for 2019 - 161967
# Prediction for 2020 - 169422
# Prediction for 2021 - 176877

# %%
plt.scatter(X_jan,Y_jan_freight_international)
plt.scatter([2019,2020,2021], predictions, marker = "^")
plt.title("All India International")
plt.ylabel("Freights")
plt.xlabel("Year")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
predictions = alg_jan_freight_domestic.predict([[2019],[2020], [2021]])
print("Prediction for 2019 -" , end = " ")
print(int(predictions[0]))
print("Prediction for 2020 -" , end = " ")
print(int(predictions[1]))
print("Prediction for 2021 -" , end = " ")
print(int(predictions[2]))
# Out:
# Prediction for 2019 - 154515
# Prediction for 2020 - 162294
# Prediction for 2021 - 170074

# %%
plt.scatter(X_jan,Y_jan_freight_domestic)
plt.scatter([2019,2020,2021], predictions, marker = "^")


plt.title("All India Domestic")
plt.ylabel("Freights")
plt.xlabel("Year")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %% [markdown]
# ## Freight Delhi International and Domestic

# %%
jan_freight_delhi = pd.read_csv("/Users/kushalgupta/Downloads/Main/1. Jan/Comma Delimited/Freight/Delhi.csv")
jan_freight_delhi = jan_freight_delhi.iloc[0:10,:]
jan_freight_delhi.columns = ["year","international","domestic","total"]
X_jan = jan_freight_delhi["year"].values.reshape(-1,1)
Y_jan_freight_international_delhi = jan_freight_delhi["international"]
alg_jan_freight_international_delhi = LinearRegression()
alg_jan_freight_international_delhi.fit(X_jan,Y_jan_freight_international_delhi)

Y_jan_freight_domestic_delhi = jan_freight_delhi["domestic"]
alg_jan_freight_domestic_delhi = LinearRegression()
alg_jan_freight_domestic_delhi.fit(X_jan,Y_jan_freight_domestic_delhi)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
predictions = alg_jan_freight_international_delhi.predict([[2019],[2020], [2021]])
print("Prediction for 2019 -" , end = " ")
print(int(predictions[0]))
print("Prediction for 2020 -" , end = " ")
print(int(predictions[1]))
print("Prediction for 2021 -" , end = " ")
print(int(predictions[2]))
# Out:
# Prediction for 2019 - 50286
# Prediction for 2020 - 53236
# Prediction for 2021 - 56186

# %%
plt.scatter(X_jan,Y_jan_freight_international_delhi)
plt.scatter([2019,2020,2021], predictions, marker = "^")
plt.title("Delhi International")
plt.ylabel("Freights")
plt.xlabel("Year")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
predictions = alg_jan_freight_domestic_delhi.predict([[2019],[2020], [2021]])
print("Prediction for 2019 -" , end = " ")
print(int(predictions[0]))
print("Prediction for 2020 -" , end = " ")
print(int(predictions[1]))
print("Prediction for 2021 -" , end = " ")
print(int(predictions[2]))
# Out:
# Prediction for 2019 - 27895
# Prediction for 2020 - 29479
# Prediction for 2021 - 31063

# %%
plt.scatter(X_jan,Y_jan_freight_domestic_delhi)
plt.scatter([2019,2020,2021], predictions, marker = "^")


plt.title("Delhi Domestic")
plt.ylabel("Freights")
plt.xlabel("Year")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %% [markdown]
# ## Passengers All India International and Domestic

# %%
jan_passengers = pd.read_csv("/Users/kushalgupta/Downloads/Main/1. Jan/Comma Delimited/Passengers/All India.csv")
jan_passengers = jan_passengers.iloc[0:10,:]
jan_passengers.columns = ["year","international","domestic","total"]
X_jan = jan_passengers["year"].values.reshape(-1,1)
Y_jan_passengers_international = jan_passengers["international"]
alg_jan_passengers_international = LinearRegression()
alg_jan_passengers_international.fit(X_jan,Y_jan_passengers_international)

Y_jan_passengers_domestic = jan_passengers["domestic"]
alg_jan_passengers_domestic = LinearRegression()
alg_jan_passengers_domestic.fit(X_jan,Y_jan_passengers_domestic)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
predictions = alg_jan_passengers_international.predict([[2019],[2020], [2021]])
print("Prediction for 2019 -" , end = " ")
print(int(predictions[0]))
print("Prediction for 2020 -" , end = " ")
print(int(predictions[1]))
print("Prediction for 2021 -" , end = " ")
print(int(predictions[2]))
# Out:
# Prediction for 2019 - 6251159
# Prediction for 2020 - 6595578
# Prediction for 2021 - 6939998

# %%
plt.scatter(X_jan,Y_jan_passengers_international)
plt.scatter([2019,2020,2021], predictions, marker = "^")


plt.title("All India International")
plt.ylabel("Passengers")
plt.xlabel("Year")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
predictions = alg_jan_passengers_domestic.predict([[2019],[2020], [2021]])
print("Prediction for 2019 -" , end = " ")
print(int(predictions[0]))
print("Prediction for 2020 -" , end = " ")
print(int(predictions[1]))
print("Prediction for 2021 -" , end = " ")
print(int(predictions[2]))
# Out:
# Prediction for 2019 - 20788401
# Prediction for 2020 - 22321670
# Prediction for 2021 - 23854939

# %%
plt.scatter(X_jan,Y_jan_passengers_domestic)
plt.scatter([2019,2020,2021], predictions, marker = "^")


plt.title("All India Domestic")
plt.ylabel("Passengers")
plt.xlabel("Year")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %% [markdown]
# ## passengers Delhi International and Domestic

# %%
jan_passengers_delhi = pd.read_csv("/Users/kushalgupta/Downloads/Main/1. Jan/Comma Delimited/Passengers/Delhi.csv")
jan_passengers_delhi = jan_passengers_delhi.iloc[0:10,:]
jan_passengers_delhi.columns = ["year","international","domestic","total"]
X_jan = jan_passengers_delhi["year"].values.reshape(-1,1)
Y_jan_passengers_international_delhi = jan_passengers_delhi["international"]
alg_jan_passengers_international_delhi = LinearRegression()
alg_jan_passengers_international_delhi.fit(X_jan,Y_jan_passengers_international_delhi)

Y_jan_passengers_domestic_delhi = jan_passengers_delhi["domestic"]
alg_jan_passengers_domestic_delhi = LinearRegression()
alg_jan_passengers_domestic_delhi.fit(X_jan,Y_jan_passengers_domestic_delhi)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
predictions = alg_jan_passengers_international_delhi.predict([[2019],[2020], [2021]])
print("Prediction for 2019 -" , end = " ")
print(int(predictions[0]))
print("Prediction for 2020 -" , end = " ")
print(int(predictions[1]))
print("Prediction for 2021 -" , end = " ")
print(int(predictions[2]))
# Out:
# Prediction for 2019 - 1662387
# Prediction for 2020 - 1760512
# Prediction for 2021 - 1858636

# %%
plt.scatter(X_jan,Y_jan_passengers_international_delhi)
plt.scatter([2019,2020,2021], predictions, marker = "^")


plt.title("Delhi International")
plt.ylabel("Passengers")
plt.xlabel("Year")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
predictions = alg_jan_passengers_domestic_delhi.predict([[2019],[2020], [2021]])
print("Prediction for 2019 -" , end = " ")
print(int(predictions[0]))
print("Prediction for 2020 -" , end = " ")
print(int(predictions[1]))
print("Prediction for 2021 -" , end = " ")
print(int(predictions[2]))
# Out:
# Prediction for 2019 - 4012654
# Prediction for 2020 - 4314092
# Prediction for 2021 - 4615531

# %%
plt.scatter(X_jan,Y_jan_passengers_domestic_delhi)
plt.scatter([2019,2020,2021], predictions, marker = "^")


plt.title("Delhi Domestic")
plt.ylabel("Passengers")
plt.xlabel("Year")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
def f(yr):
    yr = int(yr)
    return "01/" + str(yr)

# %%
jan_aircraft["month"] = "january" 
jan_aircraft["month_year"] = jan_aircraft.year.apply(f)
jan_aircraft_delhi["month"] = "january"
jan_aircraft_delhi["month_year"] = jan_aircraft_delhi.year.apply(f)

jan_freight["month"] = "january" 
jan_freight["month_year"] = jan_freight.year.apply(f)
jan_freight_delhi["month"] = "january"
jan_freight_delhi["month_year"] = jan_freight_delhi.year.apply(f)


jan_passengers["month"] = "january" 
jan_passengers["month_year"] = jan_passengers.year.apply(f)
jan_passengers_delhi["month"] = "january"
jan_passengers_delhi["month_year"] = jan_passengers_delhi.year.apply(f)

# %%
all_india_aircraft = jan_aircraft
delhi_aircraft = jan_aircraft_delhi

all_india_freight = jan_freight
delhi_freight = jan_freight_delhi

all_india_passengers = jan_passengers
delhi_passengers = jan_passengers_delhi

# %% [markdown]
# # February

# %% [markdown]
# ## Aircraft All India International and Domestic

# %%
feb_aircraft = pd.read_csv("/Users/kushalgupta/Downloads/Main/2. Feb/Comma Delimited/Aircraft/All India.csv")
feb_aircraft = feb_aircraft.iloc[0:10,:]
feb_aircraft.columns = ["year","international","domestic","total"]
X_feb = feb_aircraft["year"].values.reshape(-1,1)
Y_feb_aircraft_international = feb_aircraft["international"]
alg_feb_aircraft_international = LinearRegression()
alg_feb_aircraft_international.fit(X_jan,Y_feb_aircraft_international)

Y_feb_aircraft_domestic = jan_aircraft["domestic"]
alg_feb_aircraft_domestic = LinearRegression()
alg_feb_aircraft_domestic.fit(X_feb,Y_feb_aircraft_domestic)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
predictions = alg_feb_aircraft_international.predict([[2019],[2020], [2021]])
print("Prediction for 2019 -" , end = " ")
print(int(predictions[0]))
print("Prediction for 2020 -" , end = " ")
print(int(predictions[1]))
print("Prediction for 2021 -" , end = " ")
print(int(predictions[2]))
# Out:
# Prediction for 2019 - 34482
# Prediction for 2020 - 35885
# Prediction for 2021 - 37287

# %%
plt.scatter(X_feb,Y_feb_aircraft_international)
plt.scatter([2019,2020,2021], predictions, marker = "^")


plt.title("All India International")
plt.ylabel("Aircrafts")
plt.xlabel("Year")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
predictions = alg_feb_aircraft_domestic.predict([[2019],[2020], [2021]])
print("Prediction for 2019 -" , end = " ")
print(int(predictions[0]))
print("Prediction for 2020 -" , end = " ")
print(int(predictions[1]))
print("Prediction for 2021 -" , end = " ")
print(int(predictions[2]))
# Out:
# Prediction for 2019 - 154515
# Prediction for 2020 - 162294
# Prediction for 2021 - 170074

# %%
plt.scatter(X_feb,Y_feb_aircraft_domestic)
plt.scatter([2019,2020,2021], predictions, marker = "^")
plt.title("All India Domestic")
plt.ylabel("Aircrafts")
plt.xlabel("Year")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %% [markdown]
# ## Aircraft Delhi International and Domestic

# %%
feb_aircraft_delhi = pd.read_csv("/Users/kushalgupta/Downloads/Main/2. Feb/Comma Delimited/Aircraft/Delhi.csv")
feb_aircraft_delhi = feb_aircraft_delhi.iloc[0:10,:]
feb_aircraft_delhi.columns = ["year","international","domestic","total"]
X_feb = feb_aircraft_delhi["year"].values.reshape(-1,1)
Y_feb_aircraft_international_delhi = feb_aircraft_delhi["international"]
alg_feb_aircraft_international_delhi = LinearRegression()
alg_feb_aircraft_international_delhi.fit(X_feb,Y_feb_aircraft_international_delhi)

Y_feb_aircraft_domestic_delhi = feb_aircraft_delhi["domestic"]
alg_feb_aircraft_domestic_delhi = LinearRegression()
alg_feb_aircraft_domestic_delhi.fit(X_feb,Y_feb_aircraft_domestic_delhi)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
predictions = alg_feb_aircraft_international_delhi.predict([[2019],[2020], [2021]])
print("Prediction for 2019 -" , end = " ")
print(int(predictions[0]))
print("Prediction for 2020 -" , end = " ")
print(int(predictions[1]))
print("Prediction for 2021 -" , end = " ")
print(int(predictions[2]))
# Out:
# Prediction for 2019 - 8697
# Prediction for 2020 - 9079
# Prediction for 2021 - 9461

# %%
plt.scatter(X_feb,Y_feb_aircraft_international_delhi)
plt.scatter([2019,2020,2021], predictions, marker = "^")


plt.title("Delhi International")
plt.ylabel("Aircrafts")
plt.xlabel("Year")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
predictions = alg_feb_aircraft_domestic_delhi.predict([[2019],[2020], [2021]])
print("Prediction for 2019 -" , end = " ")
print(int(predictions[0]))
print("Prediction for 2020 -" , end = " ")
print(int(predictions[1]))
print("Prediction for 2021 -" , end = " ")
print(int(predictions[2]))
# Out:
# Prediction for 2019 - 25264
# Prediction for 2020 - 26640
# Prediction for 2021 - 28017

# %%
plt.scatter(X_feb,Y_feb_aircraft_domestic_delhi)
plt.scatter([2019,2020,2021], predictions, marker = "^")
plt.title("Delhi Domestic")
plt.ylabel("Aircrafts")
plt.xlabel("Year")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %% [markdown]
# ## Freight All India International and Domestic

# %%
feb_freight = pd.read_csv("//Users/kushalgupta/Downloads/Main/2. Feb/Comma Delimited/Freight/All India.csv")
feb_freight = feb_freight.iloc[0:10,:]
feb_freight.columns = ["year","international","domestic","total"]
X_feb = feb_freight["year"].values.reshape(-1,1)
Y_feb_freight_international = feb_freight["international"]
alg_feb_freight_international = LinearRegression()
alg_feb_freight_international.fit(X_feb,Y_feb_freight_international)

Y_feb_freight_domestic = feb_aircraft["domestic"]
alg_feb_freight_domestic = LinearRegression()
alg_feb_freight_domestic.fit(X_feb,Y_feb_freight_domestic)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
predictions = alg_feb_freight_international.predict([[2019],[2020], [2021]])
print("Prediction for 2019 -" , end = " ")
print(int(predictions[0]))
print("Prediction for 2020 -" , end = " ")
print(int(predictions[1]))
print("Prediction for 2021 -" , end = " ")
print(int(predictions[2]))
# Out:
# Prediction for 2019 - 159228
# Prediction for 2020 - 166129
# Prediction for 2021 - 173029

# %%
plt.scatter(X_feb,Y_feb_freight_international)

plt.scatter([2019,2020,2021], predictions, marker = "^")


plt.title("All India International")
plt.ylabel("Freights")
plt.xlabel("Year")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
predictions = alg_feb_freight_domestic.predict([[2019],[2020], [2021]])
print("Prediction for 2019 -" , end = " ")
print(int(predictions[0]))
print("Prediction for 2020 -" , end = " ")
print(int(predictions[1]))
print("Prediction for 2021 -" , end = " ")
print(int(predictions[2]))
# Out:
# Prediction for 2019 - 143494
# Prediction for 2020 - 150638
# Prediction for 2021 - 157783

# %%
plt.scatter(X_feb,Y_feb_freight_domestic)

plt.scatter([2019,2020,2021], predictions, marker = "^")


plt.title("All India Domestic")
plt.ylabel("Freights")
plt.xlabel("Year")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %% [markdown]
# ## Freight Delhi International and Domestic

# %%
feb_freight_delhi = pd.read_csv("/Users/kushalgupta/Downloads/Main/2. Feb/Comma Delimited/Freight/Delhi.csv")
feb_freight_delhi = feb_freight_delhi.iloc[0:10,:]
feb_freight_delhi.columns = ["year","international","domestic","total"]
X_feb = feb_freight_delhi["year"].values.reshape(-1,1)
Y_feb_freight_international_delhi = feb_freight_delhi["international"]
alg_feb_freight_international_delhi = LinearRegression()
alg_feb_freight_international_delhi.fit(X_feb,Y_feb_freight_international_delhi)

Y_feb_freight_domestic_delhi = feb_freight_delhi["domestic"]
alg_feb_freight_domestic_delhi = LinearRegression()
alg_feb_freight_domestic_delhi.fit(X_feb,Y_feb_freight_domestic_delhi)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
predictions = alg_feb_freight_international_delhi.predict([[2019],[2020], [2021]])
print("Prediction for 2019 -" , end = " ")
print(int(predictions[0]))
print("Prediction for 2020 -" , end = " ")
print(int(predictions[1]))
print("Prediction for 2021 -" , end = " ")
print(int(predictions[2]))
# Out:
# Prediction for 2019 - 47007
# Prediction for 2020 - 49513
# Prediction for 2021 - 52020

# %%
plt.scatter(X_feb,Y_feb_freight_international_delhi)

plt.scatter([2019,2020,2021], predictions, marker = "^")


plt.title("Delhi International")
plt.ylabel("Freights")
plt.xlabel("Year")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
predictions = alg_feb_freight_domestic_delhi.predict([[2019],[2020], [2021]])
print("Prediction for 2019 -" , end = " ")
print(int(predictions[0]))
print("Prediction for 2020 -" , end = " ")
print(int(predictions[1]))
print("Prediction for 2021 -" , end = " ")
print(int(predictions[2]))
# Out:
# Prediction for 2019 - 26745
# Prediction for 2020 - 28261
# Prediction for 2021 - 29777

# %%
plt.scatter(X_feb,Y_feb_freight_domestic_delhi)

plt.scatter([2019,2020,2021], predictions, marker = "^")


plt.title("Delhi Domestic")
plt.ylabel("Freights")
plt.xlabel("Year")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %% [markdown]
# ## Passengers All India International and Domestic

# %%
feb_passengers = pd.read_csv("/Users/kushalgupta/Downloads/Main/2. Feb/Comma Delimited/Passengers/All India.csv")
feb_passengers = feb_passengers.iloc[0:10,:]
feb_passengers.columns = ["year","international","domestic","total"]
X_feb = feb_passengers["year"].values.reshape(-1,1)
Y_feb_passengers_international = feb_passengers["international"]
alg_feb_passengers_international = LinearRegression()
alg_feb_passengers_international.fit(X_feb,Y_feb_passengers_international)

Y_feb_passengers_domestic = feb_passengers["domestic"]
alg_feb_passengers_domestic = LinearRegression()
alg_feb_passengers_domestic.fit(X_feb,Y_feb_passengers_domestic)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
predictions = alg_feb_passengers_international.predict([[2019],[2020], [2021]])
print("Prediction for 2019 -" , end = " ")
print(int(predictions[0]))
print("Prediction for 2020 -" , end = " ")
print(int(predictions[1]))
print("Prediction for 2021 -" , end = " ")
print(int(predictions[2]))
# Out:
# Prediction for 2019 - 5434300
# Prediction for 2020 - 5732147
# Prediction for 2021 - 6029994

# %%
plt.scatter(X_feb,Y_feb_passengers_international)

plt.scatter([2019,2020,2021], predictions, marker = "^")


plt.title("All India International")
plt.ylabel("Passengers")
plt.xlabel("Year")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
predictions = alg_feb_passengers_domestic.predict([[2019],[2020], [2021]])
print("Prediction for 2019 -" , end = " ")
print(int(predictions[0]))
print("Prediction for 2020 -" , end = " ")
print(int(predictions[1]))
print("Prediction for 2021 -" , end = " ")
print(int(predictions[2]))
# Out:
# Prediction for 2019 - 19475440
# Prediction for 2020 - 20882596
# Prediction for 2021 - 22289752

# %%
plt.scatter(X_feb,Y_feb_passengers_domestic)

plt.scatter([2019,2020,2021], predictions, marker = "^")


plt.title("All India Domestic")
plt.ylabel("Passengers")
plt.xlabel("Year")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %% [markdown]
# ## passengers Delhi International and Domestic

# %%
feb_passengers_delhi = pd.read_csv("/Users/kushalgupta/Downloads/Main/2. Feb/Comma Delimited/Passengers/Delhi.csv")
feb_passengers_delhi = feb_passengers_delhi.iloc[0:10,:]
feb_passengers_delhi.columns = ["year","international","domestic","total"]
X_feb = feb_passengers_delhi["year"].values.reshape(-1,1)
Y_feb_passengers_international_delhi = feb_passengers_delhi["international"]
alg_feb_passengers_international_delhi = LinearRegression()
alg_feb_passengers_international_delhi.fit(X_jan,Y_feb_passengers_international_delhi)

Y_feb_passengers_domestic_delhi = feb_passengers_delhi["domestic"]
alg_feb_passengers_domestic_delhi = LinearRegression()
alg_feb_passengers_domestic_delhi.fit(X_feb,Y_feb_passengers_domestic_delhi)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
predictions = alg_feb_passengers_international_delhi.predict([[2019],[2020], [2021]])
print("Prediction for 2019 -" , end = " ")
print(int(predictions[0]))
print("Prediction for 2020 -" , end = " ")
print(int(predictions[1]))
print("Prediction for 2021 -" , end = " ")
print(int(predictions[2]))
# Out:
# Prediction for 2019 - 1513067
# Prediction for 2020 - 1598046
# Prediction for 2021 - 1683026

# %%
plt.scatter(X_feb,Y_feb_passengers_international_delhi)

plt.scatter([2019,2020,2021], predictions, marker = "^")


plt.title("Delhi International")
plt.ylabel("Passengers")
plt.xlabel("Year")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
predictions = alg_feb_passengers_domestic_delhi.predict([[2019],[2020], [2021]])
print("Prediction for 2019 -" , end = " ")
print(int(predictions[0]))
print("Prediction for 2020 -" , end = " ")
print(int(predictions[1]))
print("Prediction for 2021 -" , end = " ")
print(int(predictions[2]))
# Out:
# Prediction for 2019 - 3864311
# Prediction for 2020 - 4142276
# Prediction for 2021 - 4420241

# %%
plt.scatter(X_feb,Y_feb_passengers_domestic_delhi)

plt.scatter([2019,2020,2021], predictions, marker = "^")


plt.title("Delhi Domestic")
plt.ylabel("Passengers")
plt.xlabel("Year")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
def f2(yr):
    yr = int(yr)
    return "02/" + str(yr)

# %%
feb_aircraft["month"] = "february" 
feb_aircraft["month_year"] = feb_aircraft.year.apply(f2)
feb_aircraft_delhi["month"] = "february"
feb_aircraft_delhi["month_year"] = feb_aircraft_delhi.year.apply(f2)

feb_freight["month"] = "february" 
feb_freight["month_year"] = feb_freight.year.apply(f2)
feb_freight_delhi["month"] = "february"
feb_freight_delhi["month_year"] = feb_freight_delhi.year.apply(f2)


feb_passengers["month"] = "february" 
feb_passengers["month_year"] = feb_passengers.year.apply(f2)
feb_passengers_delhi["month"] = "february"
feb_passengers_delhi["month_year"] = feb_passengers_delhi.year.apply(f2)

# %%
aircraft_dfs = [all_india_aircraft,feb_aircraft]
all_india_aircraft = pd.concat(aircraft_dfs).reset_index(drop = True)
delhi_aircraft_dfs = [delhi_aircraft,feb_aircraft_delhi]
delhi_aircraft = pd.concat(delhi_aircraft_dfs).reset_index(drop = True)

freight_dfs = [all_india_freight,feb_freight]
all_india_freight = pd.concat(freight_dfs).reset_index(drop = True)
delhi_freight_dfs = [delhi_freight,feb_freight_delhi]
delhi_freight = pd.concat(delhi_freight_dfs).reset_index(drop = True)


passengers_dfs = [all_india_passengers,feb_passengers]
all_india_passengers = pd.concat(passengers_dfs).reset_index(drop = True)
delhi_passengers_dfs = [delhi_passengers,feb_passengers_delhi]
delhi_passengers = pd.concat(delhi_passengers_dfs).reset_index(drop = True)

# %% [markdown]
# ## March

# %% [markdown]
# ## Aircraft All India International and Domestic

# %%
mar_aircraft = pd.read_csv("/Users/kushalgupta/Downloads/Main/3. Mar/Comma Delimited/Aircraft/All India.csv")
mar_aircraft = mar_aircraft.iloc[0:10,:]
mar_aircraft.columns = ["year","international","domestic","total"]
X_mar = mar_aircraft["year"].values.reshape(-1,1)
Y_mar_aircraft_international = mar_aircraft["international"]
alg_mar_aircraft_international = LinearRegression()
alg_mar_aircraft_international.fit(X_mar,Y_mar_aircraft_international)

Y_mar_aircraft_domestic = mar_aircraft["domestic"]
alg_mar_aircraft_domestic = LinearRegression()
alg_mar_aircraft_domestic.fit(X_mar,Y_mar_aircraft_domestic)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
predictions = alg_mar_aircraft_international.predict([[2019],[2020], [2021]])
print("Prediction for 2019 -" , end = " ")
print(int(predictions[0]))
print("Prediction for 2020 -" , end = " ")
print(int(predictions[1]))
print("Prediction for 2021 -" , end = " ")
print(int(predictions[2]))
# Out:
# Prediction for 2019 - 37897
# Prediction for 2020 - 39443
# Prediction for 2021 - 40989

# %%
plt.scatter([2019,2020,2021], predictions, marker = "^")

plt.scatter(X_mar,Y_mar_aircraft_international)
plt.title("All India International")
plt.ylabel("Aircrafts")
plt.xlabel("Year")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
predictions = alg_mar_aircraft_domestic.predict([[2019],[2020], [2021]])
print("Prediction for 2019 -" , end = " ")
print(int(predictions[0]))
print("Prediction for 2020 -" , end = " ")
print(int(predictions[1]))
print("Prediction for 2021 -" , end = " ")
print(int(predictions[2]))
# Out:
# Prediction for 2019 - 159569
# Prediction for 2020 - 167793
# Prediction for 2021 - 176016

# %%
plt.scatter(X_mar,Y_mar_aircraft_domestic)

plt.scatter([2019,2020,2021], predictions, marker = "^")


plt.title("All India Domestic")
plt.ylabel("Aircrafts")
plt.xlabel("Year")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %% [markdown]
# ## Aircraft Delhi International and Domestic

# %%
mar_aircraft_delhi = pd.read_csv("/Users/kushalgupta/Downloads/Main/3. Mar/Comma Delimited/Aircraft/Delhi.csv")
mar_aircraft_delhi = mar_aircraft_delhi.iloc[0:10,:]
mar_aircraft_delhi.columns = ["year","international","domestic","total"]
X_mar = mar_aircraft_delhi["year"].values.reshape(-1,1)
Y_mar_aircraft_international_delhi = mar_aircraft_delhi["international"]
alg_mar_aircraft_international_delhi = LinearRegression()
alg_mar_aircraft_international_delhi.fit(X_mar,Y_mar_aircraft_international_delhi)

Y_mar_aircraft_domestic_delhi = mar_aircraft_delhi["domestic"]
alg_mar_aircraft_domestic_delhi = LinearRegression()
alg_mar_aircraft_domestic_delhi.fit(X_mar,Y_mar_aircraft_domestic_delhi)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
predictions = alg_mar_aircraft_international_delhi.predict([[2019],[2020], [2021]])
print("Prediction for 2019 -" , end = " ")
print(int(predictions[0]))
print("Prediction for 2020 -" , end = " ")
print(int(predictions[1]))
print("Prediction for 2021 -" , end = " ")

print(int(predictions[2]))
# Out:
# Prediction for 2019 - 9657
# Prediction for 2020 - 10095
# Prediction for 2021 - 10533

# %%
plt.scatter(X_mar,Y_mar_aircraft_international_delhi)

plt.scatter([2019,2020,2021], predictions, marker = "^")


plt.title("Delhi International")
plt.ylabel("Aircrafts")
plt.xlabel("Year")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
predictions = alg_mar_aircraft_domestic_delhi.predict([[2019],[2020], [2021]])
print("Prediction for 2019 -" , end = " ")
print(int(predictions[0]))
print("Prediction for 2020 -" , end = " ")
print(int(predictions[1]))
print("Prediction for 2021 -" , end = " ")
print(int(predictions[2]))
# Out:
# Prediction for 2019 - 28792
# Prediction for 2020 - 30459
# Prediction for 2021 - 32127

# %%
plt.scatter(X_mar,Y_mar_aircraft_domestic_delhi)

plt.scatter([2019,2020,2021], predictions, marker = "^")


plt.title("Delhi Domestic")
plt.ylabel("Aircrafts")
plt.xlabel("Year")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %% [markdown]
# ## Freight All India International and Domestic

# %%
mar_freight = pd.read_csv("/Users/kushalgupta/Downloads/Main/3. Mar/Comma Delimited/Freight/All India.csv")
mar_freight = mar_freight.iloc[0:10,:]
mar_freight.columns = ["year","international","domestic","total"]
X_mar = mar_freight["year"].values.reshape(-1,1)
Y_mar_freight_international = mar_freight["international"]
alg_mar_freight_international = LinearRegression()
alg_mar_freight_international.fit(X_mar,Y_mar_freight_international)

Y_mar_freight_domestic = mar_aircraft["domestic"]
alg_mar_freight_domestic = LinearRegression()
alg_mar_freight_domestic.fit(X_mar,Y_mar_freight_domestic)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
predictions = alg_mar_freight_international.predict([[2019],[2020], [2021]])
print("Prediction for 2019 -" , end = " ")
print(int(predictions[0]))
print("Prediction for 2020 -" , end = " ")
print(int(predictions[1]))
print("Prediction for 2021 -" , end = " ")
print(int(predictions[2]))
# Out:
# Prediction for 2019 - 190956
# Prediction for 2020 - 199225
# Prediction for 2021 - 207494

# %%
plt.scatter(X_mar,Y_mar_freight_international)

plt.scatter([2019,2020,2021], predictions, marker = "^")


plt.title("All India International")
plt.ylabel("Freights")
plt.xlabel("Year")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
predictions = alg_mar_freight_domestic.predict([[2019],[2020], [2021]])
print("Prediction for 2019 -" , end = " ")
print(int(predictions[0]))
print("Prediction for 2020 -" , end = " ")
print(int(predictions[1]))
print("Prediction for 2021 -" , end = " ")
print(int(predictions[2]))
# Out:
# Prediction for 2019 - 159569
# Prediction for 2020 - 167793
# Prediction for 2021 - 176016

# %%
plt.scatter(X_mar,Y_mar_freight_domestic)

plt.scatter([2019,2020,2021], predictions, marker = "^")


plt.title("All India Domestic")
plt.ylabel("Freights")
plt.xlabel("Year")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %% [markdown]
# ## Freight Delhi International and Domestic

# %%
mar_freight_delhi = pd.read_csv("/Users/kushalgupta/Downloads/Main/3. Mar/Comma Delimited/Freight/Delhi.csv")
mar_freight_delhi = mar_freight_delhi.iloc[0:10,:]
mar_freight_delhi.columns = ["year","international","domestic","total"]
X_mar = mar_freight_delhi["year"].values.reshape(-1,1)
Y_mar_freight_international_delhi = mar_freight_delhi["international"]
alg_mar_freight_international_delhi = LinearRegression()
alg_mar_freight_international_delhi.fit(X_mar,Y_mar_freight_international_delhi)

Y_mar_freight_domestic_delhi = mar_freight_delhi["domestic"]
alg_mar_freight_domestic_delhi = LinearRegression()
alg_mar_freight_domestic_delhi.fit(X_mar,Y_mar_freight_domestic_delhi)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
predictions = alg_mar_freight_international_delhi.predict([[2019],[2020], [2021]])
print("Prediction for 2019 -" , end = " ")
print(int(predictions[0]))
print("Prediction for 2020 -" , end = " ")
print(int(predictions[1]))
print("Prediction for 2021 -" , end = " ")
print(int(predictions[2]))
# Out:
# Prediction for 2019 - 54970
# Prediction for 2020 - 57786
# Prediction for 2021 - 60601

# %%
plt.scatter(X_mar,Y_mar_freight_international_delhi)

plt.scatter([2019,2020,2021], predictions, marker = "^")


plt.title("Delhi International")
plt.ylabel("Freights")
plt.xlabel("Year")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
predictions = alg_mar_freight_domestic_delhi.predict([[2019],[2020], [2021]])
print("Prediction for 2019 -" , end = " ")
print(int(predictions[0]))
print("Prediction for 2020 -" , end = " ")
print(int(predictions[1]))
print("Prediction for 2021 -" , end = " ")
print(int(predictions[2]))
# Out:
# Prediction for 2019 - 28567
# Prediction for 2020 - 30167
# Prediction for 2021 - 31767

# %%
plt.scatter(X_mar,Y_mar_freight_domestic_delhi)

plt.scatter([2019,2020,2021], predictions, marker = "^")


plt.title("Delhi Domestic")
plt.ylabel("Freights")
plt.xlabel("Year")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %% [markdown]
# ## Passengers All India International and Domestic

# %%
mar_passengers = pd.read_csv("/Users/kushalgupta/Downloads/Main/3. Mar/Comma Delimited/Passengers/All India.csv")
mar_passengers = mar_passengers.iloc[0:10,:]
mar_passengers.columns = ["year","international","domestic","total"]
X_mar = mar_passengers["year"].values.reshape(-1,1)
Y_mar_passengers_international = mar_passengers["international"]
alg_mar_passengers_international = LinearRegression()
alg_mar_passengers_international.fit(X_mar,Y_mar_passengers_international)

Y_mar_passengers_domestic = mar_passengers["domestic"]
alg_mar_passengers_domestic = LinearRegression()
alg_mar_passengers_domestic.fit(X_mar,Y_mar_passengers_domestic)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
predictions = alg_mar_passengers_international.predict([[2019],[2020], [2021]])
print("Prediction for 2019 -" , end = " ")
print(int(predictions[0]))
print("Prediction for 2020 -" , end = " ")
print(int(predictions[1]))
print("Prediction for 2021 -" , end = " ")
print(int(predictions[2]))
# Out:
# Prediction for 2019 - 5893696
# Prediction for 2020 - 6225185
# Prediction for 2021 - 6556674

# %%
plt.scatter(X_mar,Y_mar_passengers_international)

plt.scatter([2019,2020,2021], predictions, marker = "^")


plt.title("All India International")
plt.ylabel("Passengers")
plt.xlabel("Year")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
predictions = alg_mar_passengers_domestic.predict([[2019],[2020], [2021]])
print("Prediction for 2019 -" , end = " ")
print(int(predictions[0]))
print("Prediction for 2020 -" , end = " ")
print(int(predictions[1]))
print("Prediction for 2021 -" , end = " ")
print(int(predictions[2]))
# Out:
# Prediction for 2019 - 20809161
# Prediction for 2020 - 22370883
# Prediction for 2021 - 23932604

# %%
plt.scatter(X_mar,Y_mar_passengers_domestic)

plt.scatter([2019,2020,2021], predictions, marker = "^")


plt.title("All India Domestic")
plt.ylabel("Passengers")
plt.xlabel("Year")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %% [markdown]
# ## passengers Delhi International and Domestic

# %%
mar_passengers_delhi = pd.read_csv("/Users/kushalgupta/Downloads/Main/3. Mar/Comma Delimited/Passengers/Delhi.csv")
mar_passengers_delhi = mar_passengers_delhi.iloc[0:10,:]
mar_passengers_delhi.columns = ["year","international","domestic","total"]
X_mar = mar_passengers_delhi["year"].values.reshape(-1,1)
Y_mar_passengers_international_delhi = mar_passengers_delhi["international"]
alg_mar_passengers_international_delhi = LinearRegression()
alg_mar_passengers_international_delhi.fit(X_mar,Y_mar_passengers_international_delhi)

Y_mar_passengers_domestic_delhi = mar_passengers_delhi["domestic"]
alg_mar_passengers_domestic_delhi = LinearRegression()
alg_mar_passengers_domestic_delhi.fit(X_mar,Y_mar_passengers_domestic_delhi)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
predictions = alg_mar_passengers_international_delhi.predict([[2019],[2020], [2021]])
print("Prediction for 2019 -" , end = " ")
print(int(predictions[0]))
print("Prediction for 2020 -" , end = " ")
print(int(predictions[1]))
print("Prediction for 2021 -" , end = " ")
print(int(predictions[2]))
# Out:
# Prediction for 2019 - 1652876
# Prediction for 2020 - 1746385
# Prediction for 2021 - 1839894

# %%
plt.scatter(X_mar,Y_mar_passengers_international_delhi)

plt.scatter([2019,2020,2021], predictions, marker = "^")


plt.title("Delhi International")
plt.ylabel("Passengers")
plt.xlabel("Year")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
predictions = alg_mar_passengers_domestic_delhi.predict([[2019],[2020], [2021]])
print("Prediction for 2019 -" , end = " ")
print(int(predictions[0]))
print("Prediction for 2020 -" , end = " ")
print(int(predictions[1]))
print("Prediction for 2021 -" , end = " ")
print(int(predictions[2]))
# Out:
# Prediction for 2019 - 4212810
# Prediction for 2020 - 4519925
# Prediction for 2021 - 4827040

# %%
plt.scatter(X_mar,Y_mar_passengers_domestic_delhi)

plt.scatter([2019,2020,2021], predictions, marker = "^")


plt.title("Delhi Domestic")
plt.ylabel("Passengers")
plt.xlabel("Year")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
def f3(yr):
    yr = int(yr)
    return "03/" + str(yr)

# %%
mar_aircraft["month"] = "march" 
mar_aircraft["month_year"] = mar_aircraft.year.apply(f3)
mar_aircraft_delhi["month"] = "march"
mar_aircraft_delhi["month_year"] = mar_aircraft_delhi.year.apply(f3)

mar_freight["month"] = "march" 
mar_freight["month_year"] = mar_freight.year.apply(f3)
mar_freight_delhi["month"] = "march"
mar_freight_delhi["month_year"] = mar_freight_delhi.year.apply(f3)


mar_passengers["month"] = "march" 
mar_passengers["month_year"] = mar_passengers.year.apply(f3)
mar_passengers_delhi["month"] = "march"
mar_passengers_delhi["month_year"] = mar_passengers_delhi.year.apply(f3)

# %%
aircraft_dfs = [all_india_aircraft,mar_aircraft]
all_india_aircraft = pd.concat(aircraft_dfs).reset_index(drop = True)
delhi_aircraft_dfs = [delhi_aircraft,mar_aircraft_delhi]
delhi_aircraft = pd.concat(delhi_aircraft_dfs).reset_index(drop = True)

freight_dfs = [all_india_freight,mar_freight]
all_india_freight = pd.concat(freight_dfs).reset_index(drop = True)
delhi_freight_dfs = [delhi_freight,mar_freight_delhi]
delhi_freight = pd.concat(delhi_freight_dfs).reset_index(drop = True)


passengers_dfs = [all_india_passengers,mar_passengers]
all_india_passengers = pd.concat(passengers_dfs).reset_index(drop = True)
delhi_passengers_dfs = [delhi_passengers,mar_passengers_delhi]
delhi_passengers = pd.concat(delhi_passengers_dfs).reset_index(drop = True)

# %% [markdown]
# # APRIL

# %% [markdown]
# ## Aircraft All India International and Domestic

# %%
april_aircraft = pd.read_csv("/Users/kushalgupta/Downloads/Main/4. April/Comma Delimited/Aircraft/All India.csv")
april_aircraft = april_aircraft.iloc[0:10,:]
april_aircraft.columns = ["year","international","domestic","total"]
X_april = april_aircraft["year"].values.reshape(-1,1)
Y_april_aircraft_international = april_aircraft["international"]
alg_april_aircraft_international = LinearRegression()
alg_april_aircraft_international.fit(X_april,Y_april_aircraft_international)

Y_april_aircraft_domestic = april_aircraft["domestic"]
alg_april_aircraft_domestic = LinearRegression()
alg_april_aircraft_domestic.fit(X_april,Y_april_aircraft_domestic)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
predictions = alg_april_aircraft_international.predict([[2019],[2020], [2021]])
print("Prediction for 2019 -" , end = " ")
print(int(predictions[0]))
print("Prediction for 2020 -" , end = " ")
print(int(predictions[1]))
print("Prediction for 2021 -" , end = " ")
print(int(predictions[2]))
# Out:
# Prediction for 2019 - 36791
# Prediction for 2020 - 38341
# Prediction for 2021 - 39891

# %%
plt.scatter(X_april,Y_april_aircraft_international)

plt.scatter([2019,2020,2021], predictions, marker = "^")


plt.title("All India International")
plt.ylabel("Aircrafts")
plt.xlabel("Year")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
predictions = alg_april_aircraft_domestic.predict([[2019],[2020], [2021]])
print("Prediction for 2019 -" , end = " ")
print(int(predictions[0]))
print("Prediction for 2020 -" , end = " ")
print(int(predictions[1]))
print("Prediction for 2021 -" , end = " ")
print(int(predictions[2]))
# Out:
# Prediction for 2019 - 156406
# Prediction for 2020 - 164415
# Prediction for 2021 - 172423

# %%
plt.scatter(X_april,Y_april_aircraft_domestic)

plt.scatter([2019,2020,2021], predictions, marker = "^")


plt.title("All India Domestic")
plt.ylabel("Aircrafts")
plt.xlabel("Year")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %% [markdown]
# ## Aircraft Delhi International and Domestic

# %%
april_aircraft_delhi = pd.read_csv("/Users/kushalgupta/Downloads/Main/4. April/Comma Delimited/Aircraft/Delhi.csv")
april_aircraft_delhi = april_aircraft_delhi.iloc[0:10,:]
april_aircraft_delhi.columns = ["year","international","domestic","total"]
X_april = april_aircraft_delhi["year"].values.reshape(-1,1)
Y_april_aircraft_international_delhi = april_aircraft_delhi["international"]
alg_april_aircraft_international_delhi = LinearRegression()
alg_april_aircraft_international_delhi.fit(X_april,Y_april_aircraft_international_delhi)

Y_april_aircraft_domestic_delhi = april_aircraft_delhi["domestic"]
alg_april_aircraft_domestic_delhi = LinearRegression()
alg_april_aircraft_domestic_delhi.fit(X_april,Y_april_aircraft_domestic_delhi)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
predictions = alg_april_aircraft_international_delhi.predict([[2019],[2020], [2021]])
print("Prediction for 2019 -" , end = " ")
print(int(predictions[0]))
print("Prediction for 2020 -" , end = " ")
print(int(predictions[1]))
print("Prediction for 2021 -" , end = " ")
print(int(predictions[2]))
# Out:
# Prediction for 2019 - 9294
# Prediction for 2020 - 9706
# Prediction for 2021 - 10118

# %%
plt.scatter(X_april,Y_april_aircraft_international_delhi)

plt.scatter([2019,2020,2021], predictions, marker = "^")



plt.title("Delhi International")
plt.ylabel("Aircrafts")
plt.xlabel("Year")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
predictions = alg_april_aircraft_domestic_delhi.predict([[2019],[2020], [2021]])
print("Prediction for 2019 -" , end = " ")
print(int(predictions[0]))
print("Prediction for 2020 -" , end = " ")
print(int(predictions[1]))
print("Prediction for 2021 -" , end = " ")
print(int(predictions[2]))
# Out:
# Prediction for 2019 - 28593
# Prediction for 2020 - 30281
# Prediction for 2021 - 31969

# %%
plt.scatter(X_april,Y_april_aircraft_domestic_delhi)

plt.scatter([2019,2020,2021], predictions, marker = "^")


plt.title("Delhi Domestic")
plt.ylabel("Aircrafts")
plt.xlabel("Year")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %% [markdown]
# ## Freight All India International and Domestic

# %%
april_freight = pd.read_csv("/Users/kushalgupta/Downloads/Main/4. April/Comma Delimited/Freight/All India.csv")
april_freight = april_freight.iloc[0:10,:]
april_freight.columns = ["year","international","domestic","total"]
X_april = april_freight["year"].values.reshape(-1,1)
Y_april_freight_international = april_freight["international"]
alg_april_freight_international = LinearRegression()
alg_april_freight_international.fit(X_april,Y_april_freight_international)

Y_april_freight_domestic = april_aircraft["domestic"]
alg_april_freight_domestic = LinearRegression()
alg_april_freight_domestic.fit(X_april,Y_april_freight_domestic)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
predictions = alg_april_freight_international.predict([[2019],[2020], [2021]])
print("Prediction for 2019 -" , end = " ")
print(int(predictions[0]))
print("Prediction for 2020 -" , end = " ")
print(int(predictions[1]))
print("Prediction for 2021 -" , end = " ")
print(int(predictions[2]))
# Out:
# Prediction for 2019 - 178672
# Prediction for 2020 - 186799
# Prediction for 2021 - 194927

# %%
plt.scatter(X_april,Y_april_freight_international)

plt.scatter([2019,2020,2021], predictions, marker = "^")


plt.title("All India International")
plt.ylabel("Freights")
plt.xlabel("Year")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
predictions = alg_april_freight_domestic.predict([[2019],[2020], [2021]])
print("Prediction for 2019 -" , end = " ")
print(int(predictions[0]))
print("Prediction for 2020 -" , end = " ")
print(int(predictions[1]))
print("Prediction for 2021 -" , end = " ")
print(int(predictions[2]))
# Out:
# Prediction for 2019 - 156406
# Prediction for 2020 - 164415
# Prediction for 2021 - 172423

# %%
plt.scatter(X_april,Y_april_freight_domestic)

plt.scatter([2019,2020,2021], predictions, marker = "^")


plt.title("All India Domestic")
plt.ylabel("Freights")
plt.xlabel("Year")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %% [markdown]
# ## Freight Delhi International and Domestic

# %%
april_freight_delhi = pd.read_csv("/Users/kushalgupta/Downloads/Main/4. April/Comma Delimited/Freight/Delhi.csv")
april_freight_delhi = april_freight_delhi.iloc[0:10,:]
april_freight_delhi.columns = ["year","international","domestic","total"]
X_april = april_freight_delhi["year"].values.reshape(-1,1)
Y_april_freight_international_delhi = april_freight_delhi["international"]
alg_april_freight_international_delhi = LinearRegression()
alg_april_freight_international_delhi.fit(X_april,Y_april_freight_international_delhi)

Y_april_freight_domestic_delhi = april_freight_delhi["domestic"]
alg_april_freight_domestic_delhi = LinearRegression()
alg_april_freight_domestic_delhi.fit(X_april,Y_april_freight_domestic_delhi)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
predictions = alg_april_freight_international_delhi.predict([[2019],[2020], [2021]])
print("Prediction for 2019 -" , end = " ")
print(int(predictions[0]))
print("Prediction for 2020 -" , end = " ")
print(int(predictions[1]))
print("Prediction for 2021 -" , end = " ")
print(int(predictions[2]))
# Out:
# Prediction for 2019 - 55086
# Prediction for 2020 - 58086
# Prediction for 2021 - 61086

# %%
plt.scatter(X_april,Y_april_freight_international_delhi)

plt.scatter([2019,2020,2021], predictions, marker = "^")


plt.title("Delhi International")
plt.ylabel("Freights")
plt.xlabel("Year")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
predictions = alg_april_freight_domestic_delhi.predict([[2019],[2020], [2021]])
print("Prediction for 2019 -" , end = " ")
print(int(predictions[0]))
print("Prediction for 2020 -" , end = " ")
print(int(predictions[1]))
print("Prediction for 2021 -" , end = " ")
print(int(predictions[2]))
# Out:
# Prediction for 2019 - 26751
# Prediction for 2020 - 28250
# Prediction for 2021 - 29750

# %%
plt.scatter(X_april,Y_april_freight_domestic_delhi)

plt.scatter([2019,2020,2021], predictions, marker = "^")


plt.title("Delhi Domestic")
plt.ylabel("Freights")
plt.xlabel("Year")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %% [markdown]
# ## Passengers All India International and Domestic

# %%
april_passengers = pd.read_csv("/Users/kushalgupta/Downloads/Main/4. April/Comma Delimited/Passengers/All India.csv")
april_passengers = april_passengers.iloc[0:10,:]
april_passengers.columns = ["year","international","domestic","total"]
X_april = april_passengers["year"].values.reshape(-1,1)
Y_april_passengers_international = april_passengers["international"]
alg_april_passengers_international = LinearRegression()
alg_april_passengers_international.fit(X_april,Y_april_passengers_international)

Y_april_passengers_domestic = april_passengers["domestic"]
alg_april_passengers_domestic = LinearRegression()
alg_april_passengers_domestic.fit(X_april,Y_april_passengers_domestic)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
predictions = alg_april_passengers_international.predict([[2019],[2020], [2021]])
print("Prediction for 2019 -" , end = " ")
print(int(predictions[0]))
print("Prediction for 2020 -" , end = " ")
print(int(predictions[1]))
print("Prediction for 2021 -" , end = " ")
print(int(predictions[2]))
# Out:
# Prediction for 2019 - 5724831
# Prediction for 2020 - 6050331
# Prediction for 2021 - 6375830

# %%
plt.scatter(X_april,Y_april_passengers_international)

plt.scatter([2019,2020,2021], predictions, marker = "^")


plt.title("All India International")
plt.ylabel("Passengers")
plt.xlabel("Year")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
predictions = alg_april_passengers_domestic.predict([[2019],[2020], [2021]])
print("Prediction for 2019 -" , end = " ")
print(int(predictions[0]))
print("Prediction for 2020 -" , end = " ")
print(int(predictions[1]))
print("Prediction for 2021 -" , end = " ")
print(int(predictions[2]))
# Out:
# Prediction for 2019 - 20943348
# Prediction for 2020 - 22493614
# Prediction for 2021 - 24043881

# %%
plt.scatter(X_april,Y_april_passengers_domestic)

plt.scatter([2019,2020,2021], predictions, marker = "^")


plt.title("All India Domestic")
plt.ylabel("Passengers")
plt.xlabel("Year")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %% [markdown]
# ## passengers Delhi International and Domestic

# %%
april_passengers_delhi = pd.read_csv("/Users/kushalgupta/Downloads/Main/4. April/Comma Delimited/Passengers/Delhi.csv")
april_passengers_delhi = april_passengers_delhi.iloc[0:10,:]
april_passengers_delhi.columns = ["year","international","domestic","total"]
X_april = april_passengers_delhi["year"].values.reshape(-1,1)
Y_april_passengers_international_delhi = april_passengers_delhi["international"]
alg_april_passengers_international_delhi = LinearRegression()
alg_april_passengers_international_delhi.fit(X_april,Y_april_passengers_international_delhi)

Y_april_passengers_domestic_delhi = april_passengers_delhi["domestic"]
alg_april_passengers_domestic_delhi = LinearRegression()
alg_april_passengers_domestic_delhi.fit(X_april,Y_april_passengers_domestic_delhi)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
predictions = alg_april_passengers_international_delhi.predict([[2019],[2020], [2021]])
print("Prediction for 2019 -" , end = " ")
print(int(predictions[0]))
print("Prediction for 2020 -" , end = " ")
print(int(predictions[1]))
print("Prediction for 2021 -" , end = " ")
print(int(predictions[2]))
# Out:
# Prediction for 2019 - 1493517
# Prediction for 2020 - 1581289
# Prediction for 2021 - 1669061

# %%
plt.scatter(X_april,Y_april_passengers_international_delhi)

plt.scatter([2019,2020,2021], predictions, marker = "^")


plt.title("Delhi International")
plt.ylabel("Passengers")
plt.xlabel("Year")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
predictions = alg_april_passengers_domestic_delhi.predict([[2019],[2020], [2021]])
print("Prediction for 2019 -" , end = " ")
print(int(predictions[0]))
print("Prediction for 2020 -" , end = " ")
print(int(predictions[1]))
print("Prediction for 2021 -" , end = " ")
print(int(predictions[2]))
# Out:
# Prediction for 2019 - 4207535
# Prediction for 2020 - 4516662
# Prediction for 2021 - 4825790

# %%
plt.scatter(X_april,Y_april_passengers_domestic_delhi)

plt.scatter([2019,2020,2021], predictions, marker = "^")


plt.title("Delhi Domestic")
plt.ylabel("Passengers")
plt.xlabel("Year")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
def f4(yr):
    yr = int(yr)
    return "04/" + str(yr)

# %%
april_aircraft["month"] = "april" 
april_aircraft["month_year"] = april_aircraft.year.apply(f4)
april_aircraft_delhi["month"] = "april"
april_aircraft_delhi["month_year"] = april_aircraft_delhi.year.apply(f4)

april_freight["month"] = "april" 
april_freight["month_year"] = april_freight.year.apply(f4)
april_freight_delhi["month"] = "april"
april_freight_delhi["month_year"] = april_freight_delhi.year.apply(f4)


april_passengers["month"] = "april" 
april_passengers["month_year"] = april_passengers.year.apply(f4)
april_passengers_delhi["month"] = "april"
april_passengers_delhi["month_year"] = april_passengers_delhi.year.apply(f4)

# %%
aircraft_dfs = [all_india_aircraft,april_aircraft]
all_india_aircraft = pd.concat(aircraft_dfs).reset_index(drop = True)
delhi_aircraft_dfs = [delhi_aircraft,april_aircraft_delhi]
delhi_aircraft = pd.concat(delhi_aircraft_dfs).reset_index(drop = True)

freight_dfs = [all_india_freight,april_freight]
all_india_freight = pd.concat(freight_dfs).reset_index(drop = True)
delhi_freight_dfs = [delhi_freight,april_freight_delhi]
delhi_freight = pd.concat(delhi_freight_dfs).reset_index(drop = True)


passengers_dfs = [all_india_passengers,april_passengers]
all_india_passengers = pd.concat(passengers_dfs).reset_index(drop = True)
delhi_passengers_dfs = [delhi_passengers,april_passengers_delhi]
delhi_passengers = pd.concat(delhi_passengers_dfs).reset_index(drop = True)

# %% [markdown]
# # MAY

# %% [markdown]
# ## Aircraft All India International and Domestic

# %%
may_aircraft = pd.read_csv("/Users/kushalgupta/Downloads/Main/5. May/Comma Delimited/Aircraft/All India.csv")
may_aircraft = may_aircraft.iloc[0:10,:]
may_aircraft.columns = ["year","international","domestic","total"]
X_may = may_aircraft["year"].values.reshape(-1,1)
Y_may_aircraft_international = may_aircraft["international"]
alg_may_aircraft_international = LinearRegression()
alg_may_aircraft_international.fit(X_may,Y_may_aircraft_international)

Y_may_aircraft_domestic = may_aircraft["domestic"]
alg_may_aircraft_domestic = LinearRegression()
alg_may_aircraft_domestic.fit(X_may,Y_may_aircraft_domestic)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
predictions = alg_may_aircraft_international.predict([[2019],[2020], [2021]])
print("Prediction for 2019 -" , end = " ")
print(int(predictions[0]))
print("Prediction for 2020 -" , end = " ")
print(int(predictions[1]))
print("Prediction for 2021 -" , end = " ")
print(int(predictions[2]))
# Out:
# Prediction for 2019 - 37822
# Prediction for 2020 - 39415
# Prediction for 2021 - 41008

# %%
plt.scatter(X_may,Y_may_aircraft_international)

plt.scatter([2019,2020,2021], predictions, marker = "^")


plt.title("All India International")
plt.ylabel("Aircrafts")
plt.xlabel("Year")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
predictions = alg_may_aircraft_domestic.predict([[2019],[2020], [2021]])
print("Prediction for 2019 -" , end = " ")
print(int(predictions[0]))
print("Prediction for 2020 -" , end = " ")
print(int(predictions[1]))
print("Prediction for 2021 -" , end = " ")
print(int(predictions[2]))
# Out:
# Prediction for 2019 - 166860
# Prediction for 2020 - 175672
# Prediction for 2021 - 184484

# %%
plt.scatter(X_may,Y_may_aircraft_domestic)

plt.scatter([2019,2020,2021], predictions, marker = "^")


plt.title("All India Domestic")
plt.ylabel("Aircrafts")
plt.xlabel("Year")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %% [markdown]
# ## Aircraft Delhi International and Domestic

# %%
may_aircraft_delhi = pd.read_csv("/Users/kushalgupta/Downloads/Main/5. May/Comma Delimited/Aircraft/Delhi.csv")
may_aircraft_delhi = may_aircraft_delhi.iloc[0:10,:]
may_aircraft_delhi.columns = ["year","international","domestic","total"]
X_may = may_aircraft_delhi["year"].values.reshape(-1,1)
Y_may_aircraft_international_delhi = may_aircraft_delhi["international"]
alg_may_aircraft_international_delhi = LinearRegression()
alg_may_aircraft_international_delhi.fit(X_may,Y_may_aircraft_international_delhi)

Y_may_aircraft_domestic_delhi = may_aircraft_delhi["domestic"]
alg_may_aircraft_domestic_delhi = LinearRegression()
alg_may_aircraft_domestic_delhi.fit(X_may,Y_may_aircraft_domestic_delhi)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
predictions = alg_may_aircraft_international_delhi.predict([[2019],[2020], [2021]])
print("Prediction for 2019 -" , end = " ")
print(int(predictions[0]))
print("Prediction for 2020 -" , end = " ")
print(int(predictions[1]))
print("Prediction for 2021 -" , end = " ")
print(int(predictions[2]))
# Out:
# Prediction for 2019 - 9566
# Prediction for 2020 - 9984
# Prediction for 2021 - 10403

# %%
plt.scatter(X_may,Y_may_aircraft_international_delhi)

plt.scatter([2019,2020,2021], predictions, marker = "^")


plt.title("Delhi International")
plt.ylabel("Aircrafts")
plt.xlabel("Year")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
predictions = alg_may_aircraft_domestic_delhi.predict([[2019],[2020], [2021]])
print("Prediction for 2019 -" , end = " ")
print(int(predictions[0]))
print("Prediction for 2020 -" , end = " ")
print(int(predictions[1]))
print("Prediction for 2021 -" , end = " ")
print(int(predictions[2]))
# Out:
# Prediction for 2019 - 30027
# Prediction for 2020 - 31739
# Prediction for 2021 - 33450

# %%
plt.scatter(X_may,Y_may_aircraft_domestic_delhi)

plt.scatter([2019,2020,2021], predictions, marker = "^")


plt.title("Delhi Domestic")
plt.ylabel("Aircrafts")
plt.xlabel("Year")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %% [markdown]
# ## Freight All India International and Domestic

# %%
may_freight = pd.read_csv("/Users/kushalgupta/Downloads/Main/5. May/Comma Delimited/Freight/All India.csv")
may_freight = may_freight.iloc[0:10,:]
may_freight.columns = ["year","international","domestic","total"]
X_may = may_freight["year"].values.reshape(-1,1)
Y_may_freight_international = may_freight["international"]
alg_may_freight_international = LinearRegression()
alg_may_freight_international.fit(X_may,Y_may_freight_international)

Y_may_freight_domestic = may_aircraft["domestic"]
alg_may_freight_domestic = LinearRegression()
alg_may_freight_domestic.fit(X_may,Y_may_freight_domestic)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
predictions = alg_may_freight_international.predict([[2019],[2020], [2021]])
print("Prediction for 2019 -" , end = " ")
print(int(predictions[0]))
print("Prediction for 2020 -" , end = " ")
print(int(predictions[1]))
print("Prediction for 2021 -" , end = " ")
print(int(predictions[2]))
# Out:
# Prediction for 2019 - 186757
# Prediction for 2020 - 195171
# Prediction for 2021 - 203584

# %%
plt.scatter(X_may,Y_may_freight_international)

plt.scatter([2019,2020,2021], predictions, marker = "^")


plt.title("All India International")
plt.ylabel("Freights")
plt.xlabel("Year")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
predictions = alg_may_freight_domestic.predict([[2019],[2020], [2021]])
print("Prediction for 2019 -" , end = " ")
print(int(predictions[0]))
print("Prediction for 2020 -" , end = " ")
print(int(predictions[1]))
print("Prediction for 2021 -" , end = " ")
print(int(predictions[2]))
# Out:
# Prediction for 2019 - 166860
# Prediction for 2020 - 175672
# Prediction for 2021 - 184484

# %%
plt.scatter(X_may,Y_may_freight_domestic)

plt.scatter([2019,2020,2021], predictions, marker = "^")


plt.title("All India Domestic")
plt.ylabel("Freights")
plt.xlabel("Year")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %% [markdown]
# ## Freight Delhi International and Domestic

# %%
may_freight_delhi = pd.read_csv("/Users/kushalgupta/Downloads/Main/5. May/Comma Delimited/Freight/Delhi.csv")
may_freight_delhi = may_freight_delhi.iloc[0:10,:]
may_freight_delhi.columns = ["year","international","domestic","total"]
X_may = may_freight_delhi["year"].values.reshape(-1,1)
Y_may_freight_international_delhi = may_freight_delhi["international"]
alg_may_freight_international_delhi = LinearRegression()
alg_may_freight_international_delhi.fit(X_may,Y_may_freight_international_delhi)

Y_may_freight_domestic_delhi = may_freight_delhi["domestic"]
alg_may_freight_domestic_delhi = LinearRegression()
alg_may_freight_domestic_delhi.fit(X_may,Y_may_freight_domestic_delhi)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
predictions = alg_may_freight_international_delhi.predict([[2019],[2020], [2021]])
print("Prediction for 2019 -" , end = " ")
print(int(predictions[0]))
print("Prediction for 2020 -" , end = " ")
print(int(predictions[1]))
print("Prediction for 2021 -" , end = " ")
print(int(predictions[2]))
# Out:
# Prediction for 2019 - 57582
# Prediction for 2020 - 60686
# Prediction for 2021 - 63791

# %%
plt.scatter(X_may,Y_may_freight_international_delhi)

plt.scatter([2019,2020,2021], predictions, marker = "^")


plt.title("Delhi International")
plt.ylabel("Freights")
plt.xlabel("Year")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
predictions = alg_may_freight_domestic_delhi.predict([[2019],[2020], [2021]])
print("Prediction for 2019 -" , end = " ")
print(int(predictions[0]))
print("Prediction for 2020 -" , end = " ")
print(int(predictions[1]))
print("Prediction for 2021 -" , end = " ")
print(int(predictions[2]))
# Out:
# Prediction for 2019 - 30123
# Prediction for 2020 - 31956
# Prediction for 2021 - 33790

# %%
plt.scatter(X_may,Y_may_freight_domestic_delhi)

plt.scatter([2019,2020,2021], predictions, marker = "^")


plt.title("Delhi Domestic")
plt.ylabel("Freights")
plt.xlabel("Year")
# Out:
# Text(0.5,0,'Year')

# %% [markdown]
# # #Passengers All India International and Domestic

# %%
may_passengers = pd.read_csv("/Users/kushalgupta/Downloads/Main/5. May/Comma Delimited/Passengers/All India.csv")
may_passengers = may_passengers.iloc[0:10,:]
may_passengers.columns = ["year","international","domestic","total"]
X_may = may_passengers["year"].values.reshape(-1,1)
Y_may_passengers_international = may_passengers["international"]
alg_may_passengers_international = LinearRegression()
alg_may_passengers_international.fit(X_may,Y_may_passengers_international)

Y_may_passengers_domestic = may_passengers["domestic"]
alg_may_passengers_domestic = LinearRegression()
alg_may_passengers_domestic.fit(X_may,Y_may_passengers_domestic)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
predictions = alg_may_passengers_international.predict([[2019],[2020], [2021]])
print("Prediction for 2019 -" , end = " ")
print(int(predictions[0]))
print("Prediction for 2020 -" , end = " ")
print(int(predictions[1]))
print("Prediction for 2021 -" , end = " ")
print(int(predictions[2]))
# Out:
# Prediction for 2019 - 6056555
# Prediction for 2020 - 6397812
# Prediction for 2021 - 6739069

# %%
plt.scatter(X_may,Y_may_passengers_international)

plt.scatter([2019,2020,2021], predictions, marker = "^")


plt.title("All India International")
plt.ylabel("Passengers")
plt.xlabel("Year")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
predictions = alg_may_passengers_domestic.predict([[2019],[2020], [2021]])
print("Prediction for 2019 -" , end = " ")
print(int(predictions[0]))
print("Prediction for 2020 -" , end = " ")
print(int(predictions[1]))
print("Prediction for 2021 -" , end = " ")
print(int(predictions[2]))
# Out:
# Prediction for 2019 - 22219775
# Prediction for 2020 - 23779091
# Prediction for 2021 - 25338407

# %%
plt.scatter(X_may,Y_may_passengers_domestic)

plt.scatter([2019,2020,2021], predictions, marker = "^")


plt.title("All India Domestic")
plt.ylabel("Passengers")
plt.xlabel("Year")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %% [markdown]
# # #passengers Delhi International and Domestic

# %%
may_passengers_delhi = pd.read_csv("/Users/kushalgupta/Downloads/Main/5. May/Comma Delimited/Passengers/Delhi.csv")
may_passengers_delhi = may_passengers_delhi.iloc[0:10,:]
may_passengers_delhi.columns = ["year","international","domestic","total"]
X_may = may_passengers_delhi["year"].values.reshape(-1,1)
Y_may_passengers_international_delhi = may_passengers_delhi["international"]
alg_may_passengers_international_delhi = LinearRegression()
alg_may_passengers_international_delhi.fit(X_may,Y_may_passengers_international_delhi)

Y_may_passengers_domestic_delhi = may_passengers_delhi["domestic"]
alg_may_passengers_domestic_delhi = LinearRegression()
alg_may_passengers_domestic_delhi.fit(X_may,Y_may_passengers_domestic_delhi)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
predictions = alg_may_passengers_international_delhi.predict([[2019],[2020], [2021]])
print("Prediction for 2019 -" , end = " ")
print(int(predictions[0]))
print("Prediction for 2020 -" , end = " ")
print(int(predictions[1]))
print("Prediction for 2021 -" , end = " ")
print(int(predictions[2]))
# Out:
# Prediction for 2019 - 1514790
# Prediction for 2020 - 1607791
# Prediction for 2021 - 1700792

# %%
plt.scatter(X_may,Y_may_passengers_international_delhi)

plt.scatter([2019,2020,2021], predictions, marker = "^")


plt.title("Delhi International")
plt.ylabel("Passengers")
plt.xlabel("Year")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
predictions = alg_may_passengers_domestic_delhi.predict([[2019],[2020], [2021]])
print("Prediction for 2019 -" , end = " ")
print(int(predictions[0]))
print("Prediction for 2020 -" , end = " ")
print(int(predictions[1]))
print("Prediction for 2021 -" , end = " ")
print(int(predictions[2]))
# Out:
# Prediction for 2019 - 4421155
# Prediction for 2020 - 4726356
# Prediction for 2021 - 5031557

# %%
plt.scatter(X_may,Y_may_passengers_domestic_delhi)

plt.scatter([2019,2020,2021], predictions, marker = "^")


plt.title("Delhi Domestic")
plt.ylabel("Passengers")
plt.xlabel("Year")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
def f5(yr):
    yr = int(yr)
    return "05/" + str(yr)

# %%
may_aircraft["month"] = "may" 
may_aircraft["month_year"] = may_aircraft.year.apply(f5)
may_aircraft_delhi["month"] = "may"
may_aircraft_delhi["month_year"] = may_aircraft_delhi.year.apply(f5)

may_freight["month"] = "may" 
may_freight["month_year"] = may_freight.year.apply(f5)
may_freight_delhi["month"] = "may"
may_freight_delhi["month_year"] = may_freight_delhi.year.apply(f5)


may_passengers["month"] = "may" 
may_passengers["month_year"] = may_passengers.year.apply(f5)
may_passengers_delhi["month"] = "may"
may_passengers_delhi["month_year"] = may_passengers_delhi.year.apply(f5)

# %%
aircraft_dfs = [all_india_aircraft,may_aircraft]
all_india_aircraft = pd.concat(aircraft_dfs).reset_index(drop = True)
delhi_aircraft_dfs = [delhi_aircraft,may_aircraft_delhi]
delhi_aircraft = pd.concat(delhi_aircraft_dfs).reset_index(drop = True)

freight_dfs = [all_india_freight,may_freight]
all_india_freight = pd.concat(freight_dfs).reset_index(drop = True)
delhi_freight_dfs = [delhi_freight,may_freight_delhi]
delhi_freight = pd.concat(delhi_freight_dfs).reset_index(drop = True)


passengers_dfs = [all_india_passengers,may_passengers]
all_india_passengers = pd.concat(passengers_dfs).reset_index(drop = True)
delhi_passengers_dfs = [delhi_passengers,may_passengers_delhi]
delhi_passengers = pd.concat(delhi_passengers_dfs).reset_index(drop = True)

# %% [markdown]
# # June

# %% [markdown]
# ## Aircraft All India International and Domestic

# %%
june_aircraft = pd.read_csv("/Users/kushalgupta/Downloads/Main/6. June/Comma Delimited/Aircraft/All India.csv")
june_aircraft = june_aircraft.iloc[0:10,:]
june_aircraft.columns = ["year","international","domestic","total"]
X_june = june_aircraft["year"].values.reshape(-1,1)
Y_june_aircraft_international = june_aircraft["international"]
alg_june_aircraft_international = LinearRegression()
alg_june_aircraft_international.fit(X_june,Y_june_aircraft_international)

Y_june_aircraft_domestic = june_aircraft["domestic"]
alg_june_aircraft_domestic = LinearRegression()
alg_june_aircraft_domestic.fit(X_june,Y_june_aircraft_domestic)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
predictions = alg_june_aircraft_international.predict([[2019],[2020], [2021]])
print("Prediction for 2019 -" , end = " ")
print(int(predictions[0]))
print("Prediction for 2020 -" , end = " ")
print(int(predictions[1]))
print("Prediction for 2021 -" , end = " ")
print(int(predictions[2]))
# Out:
# Prediction for 2019 - 35858
# Prediction for 2020 - 37289
# Prediction for 2021 - 38721

# %%
plt.scatter(X_june,Y_june_aircraft_international)

plt.scatter([2019,2020,2021], predictions, marker = "^")


plt.title("All India International")
plt.ylabel("Aircrafts")
plt.xlabel("Year")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
predictions = alg_june_aircraft_domestic.predict([[2019],[2020], [2021]])
print("Prediction for 2019 -" , end = " ")
print(int(predictions[0]))
print("Prediction for 2020 -" , end = " ")
print(int(predictions[1]))
print("Prediction for 2021 -" , end = " ")
print(int(predictions[2]))
# Out:
# Prediction for 2019 - 148614
# Prediction for 2020 - 155437
# Prediction for 2021 - 162259

# %%
plt.scatter(X_june,Y_june_aircraft_domestic)

plt.scatter([2019,2020,2021], predictions, marker = "^")


plt.title("All India Domestic")
plt.ylabel("Aircrafts")
plt.xlabel("Year")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %% [markdown]
# ## Aircraft Delhi International and Domestic

# %%
june_aircraft_delhi = pd.read_csv("/Users/kushalgupta/Downloads/Main/6. June/Comma Delimited/Aircraft/Delhi.csv")
june_aircraft_delhi = june_aircraft_delhi.iloc[0:10,:]
june_aircraft_delhi.columns = ["year","international","domestic","total"]
X_june = june_aircraft_delhi["year"].values.reshape(-1,1)
Y_june_aircraft_international_delhi = june_aircraft_delhi["international"]
alg_june_aircraft_international_delhi = LinearRegression()
alg_june_aircraft_international_delhi.fit(X_june,Y_june_aircraft_international_delhi)

Y_june_aircraft_domestic_delhi = june_aircraft_delhi["domestic"]
alg_june_aircraft_domestic_delhi = LinearRegression()
alg_june_aircraft_domestic_delhi.fit(X_june,Y_june_aircraft_domestic_delhi)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
predictions = alg_june_aircraft_international_delhi.predict([[2019],[2020], [2021]])
print("Prediction for 2019 -" , end = " ")
print(int(predictions[0]))
print("Prediction for 2020 -" , end = " ")
print(int(predictions[1]))
print("Prediction for 2021 -" , end = " ")
print(int(predictions[2]))
# Out:
# Prediction for 2019 - 9106
# Prediction for 2020 - 9490
# Prediction for 2021 - 9874

# %%
plt.scatter(X_june,Y_june_aircraft_international_delhi)

plt.scatter([2019,2020,2021], predictions, marker = "^")


plt.title("Delhi International")
plt.ylabel("Aircrafts")
plt.xlabel("Year")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
predictions = alg_june_aircraft_domestic_delhi.predict([[2019],[2020], [2021]])
print("Prediction for 2019 -" , end = " ")
print(int(predictions[0]))
print("Prediction for 2020 -" , end = " ")
print(int(predictions[1]))
print("Prediction for 2021 -" , end = " ")
print(int(predictions[2]))
# Out:
# Prediction for 2019 - 27986
# Prediction for 2020 - 29467
# Prediction for 2021 - 30948

# %%
plt.scatter(X_june,Y_june_aircraft_domestic_delhi)

plt.scatter([2019,2020,2021], predictions, marker = "^")


plt.title("Delhi Domestic")
plt.ylabel("Aircrafts")
plt.xlabel("Year")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %% [markdown]
# ## Freight All India International and Domestic

# %%
june_freight = pd.read_csv("/Users/kushalgupta/Downloads/Main/6. June/Comma Delimited/Freight/All India.csv")
june_freight = june_freight.iloc[0:10,:]
june_freight.columns = ["year","international","domestic","total"]
X_june = june_freight["year"].values.reshape(-1,1)
Y_june_freight_international = june_freight["international"]
alg_june_freight_international = LinearRegression()
alg_june_freight_international.fit(X_june,Y_june_freight_international)

Y_june_freight_domestic = june_aircraft["domestic"]
alg_june_freight_domestic = LinearRegression()
alg_june_freight_domestic.fit(X_june,Y_june_freight_domestic)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
predictions = alg_june_freight_international.predict([[2019],[2020], [2021]])
print("Prediction for 2019 -" , end = " ")
print(int(predictions[0]))
print("Prediction for 2020 -" , end = " ")
print(int(predictions[1]))
print("Prediction for 2021 -" , end = " ")
print(int(predictions[2]))
# Out:
# Prediction for 2019 - 177709
# Prediction for 2020 - 185191
# Prediction for 2021 - 192673

# %%
plt.scatter(X_june,Y_june_freight_international)

plt.scatter([2019,2020,2021], predictions, marker = "^")


plt.title("All India International")
plt.ylabel("Freights")
plt.xlabel("Year")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
predictions = alg_june_freight_domestic.predict([[2019],[2020], [2021]])
print("Prediction for 2019 -" , end = " ")
print(int(predictions[0]))
print("Prediction for 2020 -" , end = " ")
print(int(predictions[1]))
print("Prediction for 2021 -" , end = " ")
print(int(predictions[2]))
# Out:
# Prediction for 2019 - 148614
# Prediction for 2020 - 155437
# Prediction for 2021 - 162259

# %%
plt.scatter(X_june,Y_june_freight_domestic)

plt.scatter([2019,2020,2021], predictions, marker = "^")


plt.title("All India Domestic")
plt.ylabel("Freights")
plt.xlabel("Year")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %% [markdown]
# ## Freight Delhi International and Domestic

# %%
june_freight_delhi = pd.read_csv("/Users/kushalgupta/Downloads/Main/6. June/Comma Delimited/Freight/Delhi.csv")
june_freight_delhi = june_freight_delhi.iloc[0:10,:]
june_freight_delhi.columns = ["year","international","domestic","total"]
X_june = june_freight_delhi["year"].values.reshape(-1,1)
Y_june_freight_international_delhi = june_freight_delhi["international"]
alg_june_freight_international_delhi = LinearRegression()
alg_june_freight_international_delhi.fit(X_june,Y_june_freight_international_delhi)

Y_june_freight_domestic_delhi = june_freight_delhi["domestic"]
alg_june_freight_domestic_delhi = LinearRegression()
alg_june_freight_domestic_delhi.fit(X_june,Y_june_freight_domestic_delhi)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
predictions = alg_june_freight_international_delhi.predict([[2019],[2020], [2021]])
print("Prediction for 2019 -" , end = " ")
print(int(predictions[0]))
print("Prediction for 2020 -" , end = " ")
print(int(predictions[1]))
print("Prediction for 2021 -" , end = " ")
print(int(predictions[2]))
# Out:
# Prediction for 2019 - 55243
# Prediction for 2020 - 58371
# Prediction for 2021 - 61499

# %%
plt.scatter(X_june,Y_june_freight_international_delhi)

plt.scatter([2019,2020,2021], predictions, marker = "^")


plt.title("Delhi International")
plt.ylabel("Freights")
plt.xlabel("Year")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
predictions = alg_june_freight_domestic_delhi.predict([[2019],[2020], [2021]])
print("Prediction for 2019 -" , end = " ")
print(int(predictions[0]))
print("Prediction for 2020 -" , end = " ")
print(int(predictions[1]))
print("Prediction for 2021 -" , end = " ")
print(int(predictions[2]))
# Out:
# Prediction for 2019 - 27804
# Prediction for 2020 - 29393
# Prediction for 2021 - 30981

# %%
plt.scatter(X_june,Y_june_freight_domestic_delhi)

plt.scatter([2019,2020,2021], predictions, marker = "^")


plt.title("Delhi Domestic")
plt.ylabel("Freights")
plt.xlabel("Year")
# Out:
# Text(0.5,0,'Year')

# %% [markdown]
# ## Passengers All India International and Domestic

# %%
june_passengers = pd.read_csv("/Users/kushalgupta/Downloads/Main/6. June/Comma Delimited/Passengers/All India.csv")
june_passengers = june_passengers.iloc[0:10,:]
june_passengers.columns = ["year","international","domestic","total"]
X_june = june_passengers["year"].values.reshape(-1,1)
Y_june_passengers_international = june_passengers["international"]
alg_june_passengers_international = LinearRegression()
alg_june_passengers_international.fit(X_june,Y_june_passengers_international)

Y_june_passengers_domestic = june_passengers["domestic"]
alg_june_passengers_domestic = LinearRegression()
alg_june_passengers_domestic.fit(X_june,Y_june_passengers_domestic)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
predictions = alg_june_passengers_international.predict([[2019],[2020], [2021]])
print("Prediction for 2019 -" , end = " ")
print(int(predictions[0]))
print("Prediction for 2020 -" , end = " ")
print(int(predictions[1]))
print("Prediction for 2021 -" , end = " ")
print(int(predictions[2]))
# Out:
# Prediction for 2019 - 5537200
# Prediction for 2020 - 5824231
# Prediction for 2021 - 6111261

# %%
plt.scatter(X_june,Y_june_passengers_international)

plt.scatter([2019,2020,2021], predictions, marker = "^")


plt.title("All India International")
plt.ylabel("Passengers")
plt.xlabel("Year")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
predictions = alg_june_passengers_domestic.predict([[2019],[2020], [2021]])
print("Prediction for 2019 -" , end = " ")
print(int(predictions[0]))
print("Prediction for 2020 -" , end = " ")
print(int(predictions[1]))
print("Prediction for 2021 -" , end = " ")
print(int(predictions[2]))
# Out:
# Prediction for 2019 - 19165755
# Prediction for 2020 - 20401402
# Prediction for 2021 - 21637048

# %%
plt.scatter(X_june,Y_june_passengers_domestic)

plt.scatter([2019,2020,2021], predictions, marker = "^")


plt.title("All India Domestic")
plt.ylabel("Passengers")
plt.xlabel("Year")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %% [markdown]
# # passengers Delhi International and Domestic

# %%
june_passengers_delhi = pd.read_csv("/Users/kushalgupta/Downloads/Main/6. June/Comma Delimited/Passengers/Delhi.csv")
june_passengers_delhi = june_passengers_delhi.iloc[0:10,:]
june_passengers_delhi.columns = ["year","international","domestic","total"]
X_june = june_passengers_delhi["year"].values.reshape(-1,1)
Y_june_passengers_international_delhi = june_passengers_delhi["international"]
alg_june_passengers_international_delhi = LinearRegression()
alg_june_passengers_international_delhi.fit(X_june,Y_june_passengers_international_delhi)

Y_june_passengers_domestic_delhi = june_passengers_delhi["domestic"]
alg_june_passengers_domestic_delhi = LinearRegression()
alg_june_passengers_domestic_delhi.fit(X_june,Y_june_passengers_domestic_delhi)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
predictions = alg_june_passengers_international_delhi.predict([[2019],[2020], [2021]])
print("Prediction for 2019 -" , end = " ")
print(int(predictions[0]))
print("Prediction for 2020 -" , end = " ")
print(int(predictions[1]))
print("Prediction for 2021 -" , end = " ")
print(int(predictions[2]))
# Out:
# Prediction for 2019 - 1515494
# Prediction for 2020 - 1603033
# Prediction for 2021 - 1690573

# %%
plt.scatter(X_june,Y_june_passengers_international_delhi)

plt.scatter([2019,2020,2021], predictions, marker = "^")


plt.title("Delhi International")
plt.ylabel("Passengers")
plt.xlabel("Year")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
predictions = alg_june_passengers_domestic_delhi.predict([[2019],[2020], [2021]])
print("Prediction for 2019 -" , end = " ")
print(int(predictions[0]))
print("Prediction for 2020 -" , end = " ")
print(int(predictions[1]))
print("Prediction for 2021 -" , end = " ")
print(int(predictions[2]))
# Out:
# Prediction for 2019 - 3991613
# Prediction for 2020 - 4245518
# Prediction for 2021 - 4499423

# %%
plt.scatter(X_june,Y_june_passengers_domestic_delhi)

plt.scatter([2019,2020,2021], predictions, marker = "^")


plt.title("Delhi Domestic")
plt.ylabel("Passengers")
plt.xlabel("Year")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
def f6(yr):
    yr = int(yr)
    return "06/" + str(yr)

# %%
june_aircraft["month"] = "june" 
june_aircraft["month_year"] = june_aircraft.year.apply(f6)
june_aircraft_delhi["month"] = "june"
june_aircraft_delhi["month_year"] = june_aircraft_delhi.year.apply(f6)

june_freight["month"] = "june" 
june_freight["month_year"] = june_freight.year.apply(f6)
june_freight_delhi["month"] = "june"
june_freight_delhi["month_year"] = june_freight_delhi.year.apply(f6)


june_passengers["month"] = "june" 
june_passengers["month_year"] = june_passengers.year.apply(f6)
june_passengers_delhi["month"] = "june"
june_passengers_delhi["month_year"] = june_passengers_delhi.year.apply(f6)

# %%
aircraft_dfs = [all_india_aircraft,june_aircraft]
all_india_aircraft = pd.concat(aircraft_dfs).reset_index(drop = True)
delhi_aircraft_dfs = [delhi_aircraft,june_aircraft_delhi]
delhi_aircraft = pd.concat(delhi_aircraft_dfs).reset_index(drop = True)

freight_dfs = [all_india_freight,june_freight]
all_india_freight = pd.concat(freight_dfs).reset_index(drop = True)
delhi_freight_dfs = [delhi_freight,june_freight_delhi]
delhi_freight = pd.concat(delhi_freight_dfs).reset_index(drop = True)


passengers_dfs = [all_india_passengers,june_passengers]
all_india_passengers = pd.concat(passengers_dfs).reset_index(drop = True)
delhi_passengers_dfs = [delhi_passengers,june_passengers_delhi]
delhi_passengers = pd.concat(delhi_passengers_dfs).reset_index(drop = True)

# %% [markdown]
# # July

# %% [markdown]
# ## Aircraft All India International and Domestic

# %%
july_aircraft = pd.read_csv("/Users/kushalgupta/Downloads/Main/7. July/Comma Delimited/Aircraft/All India.csv")
july_aircraft = july_aircraft.iloc[0:10,:]
july_aircraft.columns = ["year","international","domestic","total"]
X_july = july_aircraft["year"].values.reshape(-1,1)
Y_july_aircraft_international = july_aircraft["international"]
alg_july_aircraft_international = LinearRegression()
alg_july_aircraft_international.fit(X_july,Y_july_aircraft_international)

Y_july_aircraft_domestic = july_aircraft["domestic"]
alg_july_aircraft_domestic = LinearRegression()
alg_july_aircraft_domestic.fit(X_july,Y_july_aircraft_domestic)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
predictions = alg_july_aircraft_international.predict([[2019],[2020], [2021]])
print("Prediction for 2019 -" , end = " ")
print(int(predictions[0]))
print("Prediction for 2020 -" , end = " ")
print(int(predictions[1]))
print("Prediction for 2021 -" , end = " ")
print(int(predictions[2]))
# Out:
# Prediction for 2019 - 37062
# Prediction for 2020 - 38559
# Prediction for 2021 - 40055

# %%
plt.scatter(X_july,Y_july_aircraft_international)

plt.scatter([2019,2020,2021], predictions, marker = "^")


plt.title("All India International")
plt.ylabel("Aircrafts")
plt.xlabel("Year")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
predictions = alg_july_aircraft_domestic.predict([[2019],[2020], [2021]])
print("Prediction for 2019 -" , end = " ")
print(int(predictions[0]))
print("Prediction for 2020 -" , end = " ")
print(int(predictions[1]))
print("Prediction for 2021 -" , end = " ")
print(int(predictions[2]))
# Out:
# Prediction for 2019 - 152945
# Prediction for 2020 - 160139
# Prediction for 2021 - 167333

# %%
plt.scatter(X_july,Y_july_aircraft_domestic)

plt.scatter([2019,2020,2021], predictions, marker = "^")


plt.title("All India Domestic")
plt.ylabel("Aircrafts")
plt.xlabel("Year")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %% [markdown]
# ## Aircraft Delhi International and Domestic

# %%
july_aircraft_delhi = pd.read_csv("/Users/kushalgupta/Downloads/Main/7. July/Comma Delimited/Aircraft/Delhi.csv")
july_aircraft_delhi = july_aircraft_delhi.iloc[0:10,:]
july_aircraft_delhi.columns = ["year","international","domestic","total"]
X_july = july_aircraft_delhi["year"].values.reshape(-1,1)
Y_july_aircraft_international_delhi = july_aircraft_delhi["international"]
alg_july_aircraft_international_delhi = LinearRegression()
alg_july_aircraft_international_delhi.fit(X_july,Y_july_aircraft_international_delhi)

Y_july_aircraft_domestic_delhi = july_aircraft_delhi["domestic"]
alg_july_aircraft_domestic_delhi = LinearRegression()
alg_july_aircraft_domestic_delhi.fit(X_july,Y_july_aircraft_domestic_delhi)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
predictions = alg_july_aircraft_international_delhi.predict([[2019],[2020], [2021]])
print("Prediction for 2019 -" , end = " ")
print(int(predictions[0]))
print("Prediction for 2020 -" , end = " ")
print(int(predictions[1]))
print("Prediction for 2021 -" , end = " ")
print(int(predictions[2]))
# Out:
# Prediction for 2019 - 9538
# Prediction for 2020 - 9964
# Prediction for 2021 - 10390

# %%
plt.scatter(X_july,Y_july_aircraft_international_delhi)

plt.scatter([2019,2020,2021], predictions, marker = "^")


plt.title("Delhi International")
plt.ylabel("Aircrafts")
plt.xlabel("Year")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
predictions = alg_july_aircraft_domestic_delhi.predict([[2019],[2020], [2021]])
print("Prediction for 2019 -" , end = " ")
print(int(predictions[0]))
print("Prediction for 2020 -" , end = " ")
print(int(predictions[1]))
print("Prediction for 2021 -" , end = " ")
print(int(predictions[2]))
# Out:
# Prediction for 2019 - 28266
# Prediction for 2020 - 29772
# Prediction for 2021 - 31278

# %%
plt.scatter(X_july,Y_july_aircraft_domestic_delhi)

plt.scatter([2019,2020,2021], predictions, marker = "^")


plt.title("Delhi Domestic")
plt.ylabel("Aircrafts")
plt.xlabel("Year")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %% [markdown]
# ## Freight All India International and Domestic

# %%
july_freight = pd.read_csv("/Users/kushalgupta/Downloads/Main/7. July/Comma Delimited/Freight/All India.csv")
july_freight = july_freight.iloc[0:10,:]
july_freight.columns = ["year","international","domestic","total"]
X_july = july_freight["year"].values.reshape(-1,1)
Y_july_freight_international = july_freight["international"]
alg_july_freight_international = LinearRegression()
alg_july_freight_international.fit(X_july,Y_july_freight_international)

Y_july_freight_domestic = july_aircraft["domestic"]
alg_july_freight_domestic = LinearRegression()
alg_july_freight_domestic.fit(X_july,Y_july_freight_domestic)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
predictions = alg_july_freight_international.predict([[2019],[2020], [2021]])
print("Prediction for 2019 -" , end = " ")
print(int(predictions[0]))
print("Prediction for 2020 -" , end = " ")
print(int(predictions[1]))
print("Prediction for 2021 -" , end = " ")
print(int(predictions[2]))
# Out:
# Prediction for 2019 - 172889
# Prediction for 2020 - 179326
# Prediction for 2021 - 185762

# %%
plt.scatter(X_july,Y_july_freight_international)

plt.scatter([2019,2020,2021], predictions, marker = "^")


plt.title("All India International")
plt.ylabel("Freights")
plt.xlabel("Year")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
predictions = alg_july_freight_domestic.predict([[2019],[2020], [2021]])
print("Prediction for 2019 -" , end = " ")
print(int(predictions[0]))
print("Prediction for 2020 -" , end = " ")
print(int(predictions[1]))
print("Prediction for 2021 -" , end = " ")
print(int(predictions[2]))
# Out:
# Prediction for 2019 - 152945
# Prediction for 2020 - 160139
# Prediction for 2021 - 167333

# %%
plt.scatter(X_july,Y_july_freight_domestic)

plt.scatter([2019,2020,2021], predictions, marker = "^")


plt.title("All India Domestic")
plt.ylabel("Freights")
plt.xlabel("Year")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %% [markdown]
# ## Freight Delhi International and Domestic

# %%
july_freight_delhi = pd.read_csv("/Users/kushalgupta/Downloads/Main/7. July/Comma Delimited/Freight/Delhi.csv")
july_freight_delhi = july_freight_delhi.iloc[0:10,:]
july_freight_delhi.columns = ["year","international","domestic","total"]
X_july = july_freight_delhi["year"].values.reshape(-1,1)
Y_july_freight_international_delhi = july_freight_delhi["international"]
alg_july_freight_international_delhi = LinearRegression()
alg_july_freight_international_delhi.fit(X_july,Y_july_freight_international_delhi)

Y_july_freight_domestic_delhi = july_freight_delhi["domestic"]
alg_july_freight_domestic_delhi = LinearRegression()
alg_july_freight_domestic_delhi.fit(X_july,Y_july_freight_domestic_delhi)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
predictions = alg_july_freight_international_delhi.predict([[2019],[2020], [2021]])
print("Prediction for 2019 -" , end = " ")
print(int(predictions[0]))
print("Prediction for 2020 -" , end = " ")
print(int(predictions[1]))
print("Prediction for 2021 -" , end = " ")
print(int(predictions[2]))
# Out:
# Prediction for 2019 - 53167
# Prediction for 2020 - 55868
# Prediction for 2021 - 58569

# %%
plt.scatter(X_july,Y_july_freight_international_delhi)

plt.scatter([2019,2020,2021], predictions, marker = "^")


plt.title("Delhi International")
plt.ylabel("Freights")
plt.xlabel("Year")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
predictions = alg_july_freight_domestic_delhi.predict([[2019],[2020], [2021]])
print("Prediction for 2019 -" , end = " ")
print(int(predictions[0]))
print("Prediction for 2020 -" , end = " ")
print(int(predictions[1]))
print("Prediction for 2021 -" , end = " ")
print(int(predictions[2]))
# Out:
# Prediction for 2019 - 30445
# Prediction for 2020 - 32184
# Prediction for 2021 - 33924

# %%
plt.scatter(X_july,Y_july_freight_domestic_delhi)

plt.scatter([2019,2020,2021], predictions, marker = "^")


plt.title("Delhi Domestic")
plt.ylabel("Freights")
plt.xlabel("Year")
# Out:
# Text(0.5,0,'Year')

# %% [markdown]
# ## Passengers All India International and Domestic

# %%
july_passengers = pd.read_csv("/Users/kushalgupta/Downloads/Main/7. July/Comma Delimited/Passengers/All India.csv")
july_passengers = july_passengers.iloc[0:10,:]
july_passengers.columns = ["year","international","domestic","total"]
X_july = july_passengers["year"].values.reshape(-1,1)
Y_july_passengers_international = july_passengers["international"]
alg_july_passengers_international = LinearRegression()
alg_july_passengers_international.fit(X_july,Y_july_passengers_international)

Y_july_passengers_domestic = july_passengers["domestic"]
alg_july_passengers_domestic = LinearRegression()
alg_july_passengers_domestic.fit(X_july,Y_july_passengers_domestic)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
predictions = alg_july_passengers_international.predict([[2019],[2020], [2021]])
print("Prediction for 2019 -" , end = " ")
print(int(predictions[0]))
print("Prediction for 2020 -" , end = " ")
print(int(predictions[1]))
print("Prediction for 2021 -" , end = " ")
print(int(predictions[2]))
# Out:
# Prediction for 2019 - 5626789
# Prediction for 2020 - 5922289
# Prediction for 2021 - 6217789

# %%
plt.scatter(X_july,Y_july_passengers_international)

plt.scatter([2019,2020,2021], predictions, marker = "^")


plt.title("All India International")
plt.ylabel("Passengers")
plt.xlabel("Year")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
predictions = alg_july_passengers_domestic.predict([[2019],[2020], [2021]])
print("Prediction for 2019 -" , end = " ")
print(int(predictions[0]))
print("Prediction for 2020 -" , end = " ")
print(int(predictions[1]))
print("Prediction for 2021 -" , end = " ")
print(int(predictions[2]))
# Out:
# Prediction for 2019 - 21444763
# Prediction for 2020 - 23229844
# Prediction for 2021 - 25014925

# %%
plt.scatter(X_july,Y_july_passengers_domestic)

plt.scatter([2019,2020,2021], predictions, marker = "^")


plt.title("All India Domestic")
plt.ylabel("Passengers")
plt.xlabel("Year")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %% [markdown]
# ## passengers Delhi International and Domestic

# %%
july_passengers_delhi = pd.read_csv("/Users/kushalgupta/Downloads/Main/7. July/Comma Delimited/Passengers/Delhi.csv")
july_passengers_delhi = july_passengers_delhi.iloc[0:10,:]
july_passengers_delhi.columns = ["year","international","domestic","total"]
X_july = july_passengers_delhi["year"].values.reshape(-1,1)
Y_july_passengers_international_delhi = july_passengers_delhi["international"]
alg_july_passengers_international_delhi = LinearRegression()
alg_july_passengers_international_delhi.fit(X_july,Y_july_passengers_international_delhi)

Y_july_passengers_domestic_delhi = july_passengers_delhi["domestic"]
alg_july_passengers_domestic_delhi = LinearRegression()
alg_july_passengers_domestic_delhi.fit(X_july,Y_july_passengers_domestic_delhi)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
predictions = alg_july_passengers_international_delhi.predict([[2019],[2020], [2021]])
print("Prediction for 2019 -" , end = " ")
print(int(predictions[0]))
print("Prediction for 2020 -" , end = " ")
print(int(predictions[1]))
print("Prediction for 2021 -" , end = " ")
print(int(predictions[2]))
# Out:
# Prediction for 2019 - 1481319
# Prediction for 2020 - 1566144
# Prediction for 2021 - 1650970

# %%
plt.scatter(X_july,Y_july_passengers_international_delhi)

plt.scatter([2019,2020,2021], predictions, marker = "^")


plt.title("Delhi International")
plt.ylabel("Passengers")
plt.xlabel("Year")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
predictions = alg_july_passengers_domestic_delhi.predict([[2019],[2020], [2021]])
print("Prediction for 2019 -" , end = " ")
print(int(predictions[0]))
print("Prediction for 2020 -" , end = " ")
print(int(predictions[1]))
print("Prediction for 2021 -" , end = " ")
print(int(predictions[2]))
# Out:
# Prediction for 2019 - 4001474
# Prediction for 2020 - 4281782
# Prediction for 2021 - 4562090

# %%
plt.scatter(X_july,Y_july_passengers_domestic_delhi)

plt.scatter([2019,2020,2021], predictions, marker = "^")


plt.title("Delhi Domestic")
plt.ylabel("Passengers")
plt.xlabel("Year")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
def f7(yr):
    yr = int(yr)
    return "07/" + str(yr)

# %%
july_aircraft["month"] = "july" 
july_aircraft["month_year"] = july_aircraft.year.apply(f7)
july_aircraft_delhi["month"] = "july"
july_aircraft_delhi["month_year"] = july_aircraft_delhi.year.apply(f7)

july_freight["month"] = "july" 
july_freight["month_year"] = july_freight.year.apply(f7)
july_freight_delhi["month"] = "july"
july_freight_delhi["month_year"] = july_freight_delhi.year.apply(f7)


july_passengers["month"] = "july" 
july_passengers["month_year"] = july_passengers.year.apply(f7)
july_passengers_delhi["month"] = "july"
july_passengers_delhi["month_year"] = july_passengers_delhi.year.apply(f7)

# %%
aircraft_dfs = [all_india_aircraft,july_aircraft]
all_india_aircraft = pd.concat(aircraft_dfs).reset_index(drop = True)
delhi_aircraft_dfs = [delhi_aircraft,july_aircraft_delhi]
delhi_aircraft = pd.concat(delhi_aircraft_dfs).reset_index(drop = True)

freight_dfs = [all_india_freight,july_freight]
all_india_freight = pd.concat(freight_dfs).reset_index(drop = True)
delhi_freight_dfs = [delhi_freight,july_freight_delhi]
delhi_freight = pd.concat(delhi_freight_dfs).reset_index(drop = True)


passengers_dfs = [all_india_passengers,july_passengers]
all_india_passengers = pd.concat(passengers_dfs).reset_index(drop = True)
delhi_passengers_dfs = [delhi_passengers,july_passengers_delhi]
delhi_passengers = pd.concat(delhi_passengers_dfs).reset_index(drop = True)

# %% [markdown]
# # August

# %% [markdown]
# ## Aircraft All India International and Domestic

# %%
aug_aircraft = pd.read_csv("/Users/kushalgupta/Downloads/Main/8. Aug/Comma Delimited/Aircraft/All India.csv")
aug_aircraft = aug_aircraft.iloc[0:10,:]
aug_aircraft.columns = ["year","international","domestic","total"]
X_aug = aug_aircraft["year"].values.reshape(-1,1)
Y_aug_aircraft_international = aug_aircraft["international"]
alg_aug_aircraft_international = LinearRegression()
alg_aug_aircraft_international.fit(X_aug,Y_aug_aircraft_international)

Y_aug_aircraft_domestic = aug_aircraft["domestic"]
alg_aug_aircraft_domestic = LinearRegression()
alg_aug_aircraft_domestic.fit(X_aug,Y_aug_aircraft_domestic)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
predictions = alg_aug_aircraft_international.predict([[2019],[2020], [2021]])
print("Prediction for 2019 -" , end = " ")
print(int(predictions[0]))
print("Prediction for 2020 -" , end = " ")
print(int(predictions[1]))
print("Prediction for 2021 -" , end = " ")
print(int(predictions[2]))
# Out:
# Prediction for 2019 - 37845
# Prediction for 2020 - 39434
# Prediction for 2021 - 41022

# %%
plt.scatter(X_aug,Y_aug_aircraft_international)

plt.scatter([2019,2020,2021], predictions, marker = "^")


plt.title("All India International")
plt.ylabel("Aircrafts")
plt.xlabel("Year")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
predictions = alg_aug_aircraft_domestic.predict([[2019],[2020], [2021]])
print("Prediction for 2019 -" , end = " ")
print(int(predictions[0]))
print("Prediction for 2020 -" , end = " ")
print(int(predictions[1]))
print("Prediction for 2021 -" , end = " ")
print(int(predictions[2]))
# Out:
# Prediction for 2019 - 153346
# Prediction for 2020 - 160604
# Prediction for 2021 - 167863

# %%
plt.scatter(X_aug,Y_aug_aircraft_domestic)

plt.scatter([2019,2020,2021], predictions, marker = "^")


plt.title("All India Domestic")
plt.ylabel("Aircrafts")
plt.xlabel("Year")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %% [markdown]
# ## Aircraft Delhi International and Domestic

# %%
aug_aircraft_delhi = pd.read_csv("/Users/kushalgupta/Downloads/Main/8. Aug/Comma Delimited/Aircraft/Delhi.csv")
aug_aircraft_delhi = aug_aircraft_delhi.iloc[0:10,:]
aug_aircraft_delhi.columns = ["year","international","domestic","total"]
X_aug = aug_aircraft_delhi["year"].values.reshape(-1,1)
Y_aug_aircraft_international_delhi = aug_aircraft_delhi["international"]
alg_aug_aircraft_international_delhi = LinearRegression()
alg_aug_aircraft_international_delhi.fit(X_aug,Y_aug_aircraft_international_delhi)

Y_aug_aircraft_domestic_delhi = aug_aircraft_delhi["domestic"]
alg_aug_aircraft_domestic_delhi = LinearRegression()
alg_aug_aircraft_domestic_delhi.fit(X_aug,Y_aug_aircraft_domestic_delhi)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
predictions = alg_aug_aircraft_international_delhi.predict([[2019],[2020], [2021]])
print("Prediction for 2019 -" , end = " ")
print(int(predictions[0]))
print("Prediction for 2020 -" , end = " ")
print(int(predictions[1]))
print("Prediction for 2021 -" , end = " ")
print(int(predictions[2]))
# Out:
# Prediction for 2019 - 9670
# Prediction for 2020 - 10111
# Prediction for 2021 - 10551

# %%
plt.scatter(X_aug,Y_aug_aircraft_international_delhi)

plt.scatter([2019,2020,2021], predictions, marker = "^")


plt.title("Delhi International")
plt.ylabel("Aircrafts")
plt.xlabel("Year")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
predictions = alg_aug_aircraft_domestic_delhi.predict([[2019],[2020], [2021]])
print("Prediction for 2019 -" , end = " ")
print(int(predictions[0]))
print("Prediction for 2020 -" , end = " ")
print(int(predictions[1]))
print("Prediction for 2021 -" , end = " ")
print(int(predictions[2]))
# Out:
# Prediction for 2019 - 27994
# Prediction for 2020 - 29462
# Prediction for 2021 - 30931

# %%
plt.scatter(X_aug,Y_aug_aircraft_domestic_delhi)

plt.scatter([2019,2020,2021], predictions, marker = "^")


plt.title("Delhi Domestic")
plt.ylabel("Aircrafts")
plt.xlabel("Year")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %% [markdown]
# ## Freight All India International and Domestic

# %%
aug_freight = pd.read_csv("/Users/kushalgupta/Downloads/Main/8. Aug/Comma Delimited/Freight/All India.csv")
aug_freight = aug_freight.iloc[0:10,:]
aug_freight.columns = ["year","international","domestic","total"]
X_aug = aug_freight["year"].values.reshape(-1,1)
Y_aug_freight_international = aug_freight["international"]
alg_aug_freight_international = LinearRegression()
alg_aug_freight_international.fit(X_aug,Y_aug_freight_international)

Y_aug_freight_domestic = aug_aircraft["domestic"]
alg_aug_freight_domestic = LinearRegression()
alg_aug_freight_domestic.fit(X_aug,Y_aug_freight_domestic)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
predictions = alg_aug_freight_international.predict([[2019],[2020], [2021]])
print("Prediction for 2019 -" , end = " ")
print(int(predictions[0]))
print("Prediction for 2020 -" , end = " ")
print(int(predictions[1]))
print("Prediction for 2021 -" , end = " ")
print(int(predictions[2]))
# Out:
# Prediction for 2019 - 173887
# Prediction for 2020 - 180902
# Prediction for 2021 - 187917

# %%
plt.scatter(X_aug,Y_aug_freight_international)

plt.scatter([2019,2020,2021], predictions, marker = "^")


plt.title("All India International")
plt.ylabel("Freights")
plt.xlabel("Year")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
predictions = alg_aug_freight_domestic.predict([[2019],[2020], [2021]])
print("Prediction for 2019 -" , end = " ")
print(int(predictions[0]))
print("Prediction for 2020 -" , end = " ")
print(int(predictions[1]))
print("Prediction for 2021 -" , end = " ")
print(int(predictions[2]))
# Out:
# Prediction for 2019 - 153346
# Prediction for 2020 - 160604
# Prediction for 2021 - 167863

# %%
plt.scatter(X_aug,Y_aug_freight_domestic)

plt.scatter([2019,2020,2021], predictions, marker = "^")


plt.title("All India Domestic")
plt.ylabel("Freights")
plt.xlabel("Year")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %% [markdown]
# ## Freight Delhi International and Domestic

# %%
aug_freight_delhi = pd.read_csv("/Users/kushalgupta/Downloads/Main/8. Aug/Comma Delimited/Freight/Delhi.csv")
aug_freight_delhi = aug_freight_delhi.iloc[0:10,:]
aug_freight_delhi.columns = ["year","international","domestic","total"]
X_aug = aug_freight_delhi["year"].values.reshape(-1,1)
Y_aug_freight_international_delhi = aug_freight_delhi["international"]
alg_aug_freight_international_delhi = LinearRegression()
alg_aug_freight_international_delhi.fit(X_aug,Y_aug_freight_international_delhi)

Y_aug_freight_domestic_delhi = aug_freight_delhi["domestic"]
alg_aug_freight_domestic_delhi = LinearRegression()
alg_aug_freight_domestic_delhi.fit(X_aug,Y_aug_freight_domestic_delhi)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
predictions = alg_aug_freight_international_delhi.predict([[2019],[2020], [2021]])
print("Prediction for 2019 -" , end = " ")
print(int(predictions[0]))
print("Prediction for 2020 -" , end = " ")
print(int(predictions[1]))
print("Prediction for 2021 -" , end = " ")
print(int(predictions[2]))
# Out:
# Prediction for 2019 - 53755
# Prediction for 2020 - 56702
# Prediction for 2021 - 59649

# %%
plt.scatter(X_aug,Y_aug_freight_international_delhi)

plt.scatter([2019,2020,2021], predictions, marker = "^")


plt.title("Delhi International")
plt.ylabel("Freights")
plt.xlabel("Year")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
predictions = alg_aug_freight_domestic_delhi.predict([[2019],[2020], [2021]])
print("Prediction for 2019 -" , end = " ")
print(int(predictions[0]))
print("Prediction for 2020 -" , end = " ")
print(int(predictions[1]))
print("Prediction for 2021 -" , end = " ")
print(int(predictions[2]))
# Out:
# Prediction for 2019 - 29073
# Prediction for 2020 - 30534
# Prediction for 2021 - 31996

# %%
plt.scatter(X_aug,Y_aug_freight_domestic_delhi)

plt.scatter([2019,2020,2021], predictions, marker = "^")


plt.title("Delhi Domestic")
plt.ylabel("Freights")
plt.xlabel("Year")
# Out:
# Text(0.5,0,'Year')

# %% [markdown]
# ## Passengers All India International and Domestic

# %%
aug_passengers = pd.read_csv("/Users/kushalgupta/Downloads/Main/8. Aug/Comma Delimited/Passengers/All India.csv")
aug_passengers = aug_passengers.iloc[0:10,:]
aug_passengers.columns = ["year","international","domestic","total"]
X_aug = aug_passengers["year"].values.reshape(-1,1)
Y_aug_passengers_international = aug_passengers["international"]
alg_aug_passengers_international = LinearRegression()
alg_aug_passengers_international.fit(X_aug,Y_aug_passengers_international)

Y_aug_passengers_domestic = aug_passengers["domestic"]
alg_aug_passengers_domestic = LinearRegression()
alg_aug_passengers_domestic.fit(X_aug,Y_aug_passengers_domestic)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
predictions = alg_aug_passengers_international.predict([[2019],[2020], [2021]])
print("Prediction for 2019 -" , end = " ")
print(int(predictions[0]))
print("Prediction for 2020 -" , end = " ")
print(int(predictions[1]))
print("Prediction for 2021 -" , end = " ")
print(int(predictions[2]))
# Out:
# Prediction for 2019 - 5825444
# Prediction for 2020 - 6146286
# Prediction for 2021 - 6467128

# %%
plt.scatter(X_aug,Y_aug_passengers_international)

plt.scatter([2019,2020,2021], predictions, marker = "^")


plt.title("All India International")
plt.ylabel("Passengers")
plt.xlabel("Year")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
predictions = alg_aug_passengers_domestic.predict([[2019],[2020], [2021]])
print("Prediction for 2019 -" , end = " ")
print(int(predictions[0]))
print("Prediction for 2020 -" , end = " ")
print(int(predictions[1]))
print("Prediction for 2021 -" , end = " ")
print(int(predictions[2]))
# Out:
# Prediction for 2019 - 20025212
# Prediction for 2020 - 21439757
# Prediction for 2021 - 22854302

# %%
plt.scatter(X_aug,Y_aug_passengers_domestic)

plt.scatter([2019,2020,2021], predictions, marker = "^")


plt.title("All India Domestic")
plt.ylabel("Passengers")
plt.xlabel("Year")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %% [markdown]
# ## passengers Delhi International and Domestic

# %%
aug_passengers_delhi = pd.read_csv("/Users/kushalgupta/Downloads/Main/8. Aug/Comma Delimited/Passengers/Delhi.csv")
aug_passengers_delhi = aug_passengers_delhi.iloc[0:10,:]
aug_passengers_delhi.columns = ["year","international","domestic","total"]
X_aug = aug_passengers_delhi["year"].values.reshape(-1,1)
Y_aug_passengers_international_delhi = aug_passengers_delhi["international"]
alg_aug_passengers_international_delhi = LinearRegression()
alg_aug_passengers_international_delhi.fit(X_aug,Y_aug_passengers_international_delhi)

Y_aug_passengers_domestic_delhi = aug_passengers_delhi["domestic"]
alg_aug_passengers_domestic_delhi = LinearRegression()
alg_aug_passengers_domestic_delhi.fit(X_aug,Y_aug_passengers_domestic_delhi)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
predictions = alg_aug_passengers_international_delhi.predict([[2019],[2020], [2021]])
print("Prediction for 2019 -" , end = " ")
print(int(predictions[0]))
print("Prediction for 2020 -" , end = " ")
print(int(predictions[1]))
print("Prediction for 2021 -" , end = " ")
print(int(predictions[2]))
# Out:
# Prediction for 2019 - 1530307
# Prediction for 2020 - 1620518
# Prediction for 2021 - 1710728

# %%
plt.scatter(X_aug,Y_aug_passengers_international_delhi)

plt.scatter([2019,2020,2021], predictions, marker = "^")


plt.title("Delhi International")
plt.ylabel("Passengers")
plt.xlabel("Year")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
predictions = alg_aug_passengers_domestic_delhi.predict([[2019],[2020], [2021]])
print("Prediction for 2019 -" , end = " ")
print(int(predictions[0]))
print("Prediction for 2020 -" , end = " ")
print(int(predictions[1]))
print("Prediction for 2021 -" , end = " ")
print(int(predictions[2]))
# Out:
# Prediction for 2019 - 3990691
# Prediction for 2020 - 4276666
# Prediction for 2021 - 4562641

# %%
plt.scatter(X_aug,Y_aug_passengers_domestic_delhi)

plt.scatter([2019,2020,2021], predictions, marker = "^")


plt.title("Delhi Domestic")
plt.ylabel("Passengers")
plt.xlabel("Year")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
def f8(yr):
    yr = int(yr)
    return "08/" + str(yr)

# %%
aug_aircraft["month"] = "aug" 
aug_aircraft["month_year"] = aug_aircraft.year.apply(f8)
aug_aircraft_delhi["month"] = "aug"
aug_aircraft_delhi["month_year"] = aug_aircraft_delhi.year.apply(f8)

aug_freight["month"] = "aug" 
aug_freight["month_year"] = aug_freight.year.apply(f8)
aug_freight_delhi["month"] = "aug"
aug_freight_delhi["month_year"] = aug_freight_delhi.year.apply(f8)


aug_passengers["month"] = "aug" 
aug_passengers["month_year"] = aug_passengers.year.apply(f8)
aug_passengers_delhi["month"] = "aug"
aug_passengers_delhi["month_year"] = aug_passengers_delhi.year.apply(f8)

# %%
aircraft_dfs = [all_india_aircraft,aug_aircraft]
all_india_aircraft = pd.concat(aircraft_dfs).reset_index(drop = True)
delhi_aircraft_dfs = [delhi_aircraft,aug_aircraft_delhi]
delhi_aircraft = pd.concat(delhi_aircraft_dfs).reset_index(drop = True)

freight_dfs = [all_india_freight,aug_freight]
all_india_freight = pd.concat(freight_dfs).reset_index(drop = True)
delhi_freight_dfs = [delhi_freight,aug_freight_delhi]
delhi_freight = pd.concat(delhi_freight_dfs).reset_index(drop = True)


passengers_dfs = [all_india_passengers,aug_passengers]
all_india_passengers = pd.concat(passengers_dfs).reset_index(drop = True)
delhi_passengers_dfs = [delhi_passengers,aug_passengers_delhi]
delhi_passengers = pd.concat(delhi_passengers_dfs).reset_index(drop = True)

# %% [markdown]
# # September

# %% [markdown]
# ## Aircraft All India International and Domestic

# %%
sept_aircraft = pd.read_csv("/Users/kushalgupta/Downloads/Main/09. Sept/Comma Delimited/Aircraft/All India.csv")
sept_aircraft = sept_aircraft.iloc[0:10,:]
sept_aircraft.columns = ["year","international","domestic","total"]
X_sept = sept_aircraft["year"].values.reshape(-1,1)
Y_sept_aircraft_international = sept_aircraft["international"]
alg_sept_aircraft_international = LinearRegression()
alg_sept_aircraft_international.fit(X_sept,Y_sept_aircraft_international)

Y_sept_aircraft_domestic = sept_aircraft["domestic"]
alg_sept_aircraft_domestic = LinearRegression()
alg_sept_aircraft_domestic.fit(X_sept,Y_sept_aircraft_domestic)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
predictions = alg_sept_aircraft_international.predict([[2019],[2020], [2021]])
print("Prediction for 2019 -" , end = " ")
print(int(predictions[0]))
print("Prediction for 2020 -" , end = " ")
print(int(predictions[1]))
print("Prediction for 2021 -" , end = " ")
print(int(predictions[2]))
# Out:
# Prediction for 2019 - 37462
# Prediction for 2020 - 39028
# Prediction for 2021 - 40594

# %%
plt.scatter(X_sept,Y_sept_aircraft_international)

plt.scatter([2019,2020,2021], predictions, marker = "^")


plt.title("All India International")
plt.ylabel("Aircrafts")
plt.xlabel("Year")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
predictions = alg_sept_aircraft_domestic.predict([[2019],[2020], [2021]])
print("Prediction for 2019 -" , end = " ")
print(int(predictions[0]))
print("Prediction for 2020 -" , end = " ")
print(int(predictions[1]))
print("Prediction for 2021 -" , end = " ")
print(int(predictions[2]))
# Out:
# Prediction for 2019 - 152689
# Prediction for 2020 - 160397
# Prediction for 2021 - 168105

# %%
plt.scatter(X_sept,Y_sept_aircraft_domestic)

plt.scatter([2019,2020,2021], predictions, marker = "^")


plt.title("All India Domestic")
plt.ylabel("Aircrafts")
plt.xlabel("Year")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %% [markdown]
# ## Aircraft Delhi International and Domestic

# %%
sept_aircraft_delhi = pd.read_csv("/Users/kushalgupta/Downloads/Main/09. Sept/Comma Delimited/Aircraft/Delhi.csv")
sept_aircraft_delhi = sept_aircraft_delhi.iloc[0:10,:]
sept_aircraft_delhi.columns = ["year","international","domestic","total"]
X_sept = sept_aircraft_delhi["year"].values.reshape(-1,1)
Y_sept_aircraft_international_delhi = sept_aircraft_delhi["international"]
alg_sept_aircraft_international_delhi = LinearRegression()
alg_sept_aircraft_international_delhi.fit(X_sept,Y_sept_aircraft_international_delhi)

Y_sept_aircraft_domestic_delhi = sept_aircraft_delhi["domestic"]
alg_sept_aircraft_domestic_delhi = LinearRegression()
alg_sept_aircraft_domestic_delhi.fit(X_sept,Y_sept_aircraft_domestic_delhi)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
predictions = alg_sept_aircraft_international_delhi.predict([[2019],[2020], [2021]])
print("Prediction for 2019 -" , end = " ")
print(int(predictions[0]))
print("Prediction for 2020 -" , end = " ")
print(int(predictions[1]))
print("Prediction for 2021 -" , end = " ")
print(int(predictions[2]))
# Out:
# Prediction for 2019 - 9452
# Prediction for 2020 - 9874
# Prediction for 2021 - 10295

# %%
plt.scatter(X_sept,Y_sept_aircraft_international_delhi)

plt.scatter([2019,2020,2021], predictions, marker = "^")


plt.title("Delhi International")
plt.ylabel("Aircrafts")
plt.xlabel("Year")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
predictions = alg_sept_aircraft_domestic_delhi.predict([[2019],[2020], [2021]])
print("Prediction for 2019 -" , end = " ")
print(int(predictions[0]))
print("Prediction for 2020 -" , end = " ")
print(int(predictions[1]))
print("Prediction for 2021 -" , end = " ")
print(int(predictions[2]))
# Out:
# Prediction for 2019 - 27715
# Prediction for 2020 - 29252
# Prediction for 2021 - 30789

# %%
plt.scatter(X_sept,Y_sept_aircraft_domestic_delhi)

plt.scatter([2019,2020,2021], predictions, marker = "^")


plt.title("Delhi Domestic")
plt.ylabel("Aircrafts")
plt.xlabel("Year")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %% [markdown]
# ## Freight All India International and Domestic

# %%
sept_freight = pd.read_csv("/Users/kushalgupta/Downloads/Main/09. Sept/Comma Delimited/Freight/All India.csv")
sept_freight = sept_freight.iloc[0:10,:]
sept_freight.columns = ["year","international","domestic","total"]
X_sept = sept_freight["year"].values.reshape(-1,1)
Y_sept_freight_international = sept_freight["international"]
alg_sept_freight_international = LinearRegression()
alg_sept_freight_international.fit(X_sept,Y_sept_freight_international)

Y_sept_freight_domestic = sept_aircraft["domestic"]
alg_sept_freight_domestic = LinearRegression()
alg_sept_freight_domestic.fit(X_sept,Y_sept_freight_domestic)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
predictions = alg_sept_freight_international.predict([[2019],[2020], [2021]])
print("Prediction for 2019 -" , end = " ")
print(int(predictions[0]))
print("Prediction for 2020 -" , end = " ")
print(int(predictions[1]))
print("Prediction for 2021 -" , end = " ")
print(int(predictions[2]))
# Out:
# Prediction for 2019 - 173978
# Prediction for 2020 - 181179
# Prediction for 2021 - 188379

# %%
plt.scatter(X_sept,Y_sept_freight_international)

plt.scatter([2019,2020,2021], predictions, marker = "^")


plt.title("All India International")
plt.ylabel("Freights")
plt.xlabel("Year")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
predictions = alg_sept_freight_domestic.predict([[2019],[2020], [2021]])
print("Prediction for 2019 -" , end = " ")
print(int(predictions[0]))
print("Prediction for 2020 -" , end = " ")
print(int(predictions[1]))
print("Prediction for 2021 -" , end = " ")
print(int(predictions[2]))
# Out:
# Prediction for 2019 - 152689
# Prediction for 2020 - 160397
# Prediction for 2021 - 168105

# %%
plt.scatter(X_sept,Y_sept_freight_domestic)

plt.scatter([2019,2020,2021], predictions, marker = "^")


plt.title("All India Domestic")
plt.ylabel("Freights")
plt.xlabel("Year")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %% [markdown]
# ## Freight Delhi International and Domestic

# %%
sept_freight_delhi = pd.read_csv("/Users/kushalgupta/Downloads/Main/09. Sept/Comma Delimited/Freight/Delhi.csv")
sept_freight_delhi = sept_freight_delhi.iloc[0:10,:]
sept_freight_delhi.columns = ["year","international","domestic","total"]
X_sept = sept_freight_delhi["year"].values.reshape(-1,1)
Y_sept_freight_international_delhi = sept_freight_delhi["international"]
alg_sept_freight_international_delhi = LinearRegression()
alg_sept_freight_international_delhi.fit(X_sept,Y_sept_freight_international_delhi)

Y_sept_freight_domestic_delhi = sept_freight_delhi["domestic"]
alg_sept_freight_domestic_delhi = LinearRegression()
alg_sept_freight_domestic_delhi.fit(X_sept,Y_sept_freight_domestic_delhi)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
predictions = alg_sept_freight_international_delhi.predict([[2019],[2020], [2021]])
print("Prediction for 2019 -" , end = " ")
print(int(predictions[0]))
print("Prediction for 2020 -" , end = " ")
print(int(predictions[1]))
print("Prediction for 2021 -" , end = " ")
print(int(predictions[2]))
# Out:
# Prediction for 2019 - 55091
# Prediction for 2020 - 58136
# Prediction for 2021 - 61182

# %%
plt.scatter(X_sept,Y_sept_freight_international_delhi)

plt.scatter([2019,2020,2021], predictions, marker = "^")


plt.title("Delhi International")
plt.ylabel("Freights")
plt.xlabel("Year")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
predictions = alg_sept_freight_domestic_delhi.predict([[2019],[2020], [2021]])
print("Prediction for 2019 -" , end = " ")
print(int(predictions[0]))
print("Prediction for 2020 -" , end = " ")
print(int(predictions[1]))
print("Prediction for 2021 -" , end = " ")
print(int(predictions[2]))
# Out:
# Prediction for 2019 - 30791
# Prediction for 2020 - 32424
# Prediction for 2021 - 34057

# %%
plt.scatter(X_sept,Y_sept_freight_domestic_delhi)

plt.scatter([2019,2020,2021], predictions, marker = "^")


plt.title("Delhi Domestic")
plt.ylabel("Freights")
plt.xlabel("Year")
# Out:
# Text(0.5,0,'Year')

# %% [markdown]
# ## Passengers All India International and Domestic

# %%
sept_passengers = pd.read_csv("/Users/kushalgupta/Downloads/Main/09. Sept/Comma Delimited/Passengers/All India.csv")
sept_passengers = sept_passengers.iloc[0:10,:]
sept_passengers.columns = ["year","international","domestic","total"]
X_sept = sept_passengers["year"].values.reshape(-1,1)
Y_sept_passengers_international = sept_passengers["international"]
alg_sept_passengers_international = LinearRegression()
alg_sept_passengers_international.fit(X_sept,Y_sept_passengers_international)

Y_sept_passengers_domestic = sept_passengers["domestic"]
alg_sept_passengers_domestic = LinearRegression()
alg_sept_passengers_domestic.fit(X_sept,Y_sept_passengers_domestic)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
predictions = alg_sept_passengers_international.predict([[2019],[2020], [2021]])
print("Prediction for 2019 -" , end = " ")
print(int(predictions[0]))
print("Prediction for 2020 -" , end = " ")
print(int(predictions[1]))
print("Prediction for 2021 -" , end = " ")
print(int(predictions[2]))
# Out:
# Prediction for 2019 - 5531322
# Prediction for 2020 - 5839165
# Prediction for 2021 - 6147009

# %%
plt.scatter(X_sept,Y_sept_passengers_international)

plt.scatter([2019,2020,2021], predictions, marker = "^")


plt.title("All India International")
plt.ylabel("Passengers")
plt.xlabel("Year")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
predictions = alg_sept_passengers_domestic.predict([[2019],[2020], [2021]])
print("Prediction for 2019 -" , end = " ")
print(int(predictions[0]))
print("Prediction for 2020 -" , end = " ")
print(int(predictions[1]))
print("Prediction for 2021 -" , end = " ")
print(int(predictions[2]))
# Out:
# Prediction for 2019 - 19760492
# Prediction for 2020 - 21202861
# Prediction for 2021 - 22645230

# %%
plt.scatter(X_sept,Y_sept_passengers_domestic)

plt.scatter([2019,2020,2021], predictions, marker = "^")


plt.title("All India Domestic")
plt.ylabel("Passengers")
plt.xlabel("Year")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %% [markdown]
# ## passengers Delhi International and Domestic

# %%
sept_passengers_delhi = pd.read_csv("/Users/kushalgupta/Downloads/Main/09. Sept/Comma Delimited/Passengers/Delhi.csv")
sept_passengers_delhi = sept_passengers_delhi.iloc[0:10,:]
sept_passengers_delhi.columns = ["year","international","domestic","total"]
X_sept = sept_passengers_delhi["year"].values.reshape(-1,1)
Y_sept_passengers_international_delhi = sept_passengers_delhi["international"]
alg_sept_passengers_international_delhi = LinearRegression()
alg_sept_passengers_international_delhi.fit(X_sept,Y_sept_passengers_international_delhi)

Y_sept_passengers_domestic_delhi = sept_passengers_delhi["domestic"]
alg_sept_passengers_domestic_delhi = LinearRegression()
alg_sept_passengers_domestic_delhi.fit(X_sept,Y_sept_passengers_domestic_delhi)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
predictions = alg_sept_passengers_international_delhi.predict([[2019],[2020], [2021]])
print("Prediction for 2019 -" , end = " ")
print(int(predictions[0]))
print("Prediction for 2020 -" , end = " ")
print(int(predictions[1]))
print("Prediction for 2021 -" , end = " ")
print(int(predictions[2]))
# Out:
# Prediction for 2019 - 1488006
# Prediction for 2020 - 1575516
# Prediction for 2021 - 1663026

# %%
plt.scatter(X_sept,Y_sept_passengers_international_delhi)

plt.scatter([2019,2020,2021], predictions, marker = "^")


plt.title("Delhi International")
plt.ylabel("Passengers")
plt.xlabel("Year")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
predictions = alg_sept_passengers_domestic_delhi.predict([[2019],[2020], [2021]])
print("Prediction for 2019 -" , end = " ")
print(int(predictions[0]))
print("Prediction for 2020 -" , end = " ")
print(int(predictions[1]))
print("Prediction for 2021 -" , end = " ")
print(int(predictions[2]))
# Out:
# Prediction for 2019 - 3967497
# Prediction for 2020 - 4263931
# Prediction for 2021 - 4560364

# %%
plt.scatter(X_sept,Y_sept_passengers_domestic_delhi)

plt.scatter([2019,2020,2021], predictions, marker = "^")


plt.title("Delhi Domestic")
plt.ylabel("Passengers")
plt.xlabel("Year")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
def f9(yr):
    yr = int(yr)
    return "09/" + str(yr)

# %%
sept_aircraft["month"] = "sept" 
sept_aircraft["month_year"] = sept_aircraft.year.apply(f9)
sept_aircraft_delhi["month"] = "sept"
sept_aircraft_delhi["month_year"] = sept_aircraft_delhi.year.apply(f9)

sept_freight["month"] = "sept" 
sept_freight["month_year"] = sept_freight.year.apply(f9)
sept_freight_delhi["month"] = "sept"
sept_freight_delhi["month_year"] = sept_freight_delhi.year.apply(f9)


sept_passengers["month"] = "sept" 
sept_passengers["month_year"] = sept_passengers.year.apply(f9)
sept_passengers_delhi["month"] = "sept"
sept_passengers_delhi["month_year"] = sept_passengers_delhi.year.apply(f9)

# %%
aircraft_dfs = [all_india_aircraft,sept_aircraft]
all_india_aircraft = pd.concat(aircraft_dfs).reset_index(drop = True)
delhi_aircraft_dfs = [delhi_aircraft,sept_aircraft_delhi]
delhi_aircraft = pd.concat(delhi_aircraft_dfs).reset_index(drop = True)

freight_dfs = [all_india_freight,sept_freight]
all_india_freight = pd.concat(freight_dfs).reset_index(drop = True)
delhi_freight_dfs = [delhi_freight,sept_freight_delhi]
delhi_freight = pd.concat(delhi_freight_dfs).reset_index(drop = True)


passengers_dfs = [all_india_passengers,sept_passengers]
all_india_passengers = pd.concat(passengers_dfs).reset_index(drop = True)
delhi_passengers_dfs = [delhi_passengers,sept_passengers_delhi]
delhi_passengers = pd.concat(delhi_passengers_dfs).reset_index(drop = True)

# %% [markdown]
# # October

# %% [markdown]
# ## Aircraft All India International and Domestic

# %%
oct_aircraft = pd.read_csv("/Users/kushalgupta/Downloads/Main/10. Oct/Comma Delimited/Aircraft/All India.csv")
oct_aircraft = oct_aircraft.iloc[0:10,:]
oct_aircraft.columns = ["year","international","domestic","total"]
X_oct = oct_aircraft["year"].values.reshape(-1,1)
Y_oct_aircraft_international = oct_aircraft["international"]
alg_oct_aircraft_international = LinearRegression()
alg_oct_aircraft_international.fit(X_oct,Y_oct_aircraft_international)

Y_oct_aircraft_domestic = oct_aircraft["domestic"]
alg_oct_aircraft_domestic = LinearRegression()
alg_oct_aircraft_domestic.fit(X_oct,Y_oct_aircraft_domestic)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
predictions = alg_oct_aircraft_international.predict([[2019],[2020], [2021]])
print("Prediction for 2019 -" , end = " ")
print(int(predictions[0]))
print("Prediction for 2020 -" , end = " ")
print(int(predictions[1]))
print("Prediction for 2021 -" , end = " ")
print(int(predictions[2]))
# Out:
# Prediction for 2019 - 38454
# Prediction for 2020 - 39917
# Prediction for 2021 - 41380

# %%
plt.scatter(X_oct,Y_oct_aircraft_international)

plt.scatter([2019,2020,2021], predictions, marker = "^")


plt.title("All India International")
plt.ylabel("Aircrafts")
plt.xlabel("Year")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
predictions = alg_oct_aircraft_domestic.predict([[2019],[2020], [2021]])
print("Prediction for 2019 -" , end = " ")
print(int(predictions[0]))
print("Prediction for 2020 -" , end = " ")
print(int(predictions[1]))
print("Prediction for 2021 -" , end = " ")
print(int(predictions[2]))
# Out:
# Prediction for 2019 - 162860
# Prediction for 2020 - 171162
# Prediction for 2021 - 179465

# %%
plt.scatter(X_oct,Y_oct_aircraft_domestic)

plt.scatter([2019,2020,2021], predictions, marker = "^")


plt.title("All India Domestic")
plt.ylabel("Aircrafts")
plt.xlabel("Year")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %% [markdown]
# ## Aircraft Delhi International and Domestic

# %%
oct_aircraft_delhi = pd.read_csv("/Users/kushalgupta/Downloads/Main/10. Oct/Comma Delimited/Aircraft/Delhi.csv")
oct_aircraft_delhi = oct_aircraft_delhi.iloc[0:10,:]
oct_aircraft_delhi.columns = ["year","international","domestic","total"]
X_oct = oct_aircraft_delhi["year"].values.reshape(-1,1)
Y_oct_aircraft_international_delhi = oct_aircraft_delhi["international"]
alg_oct_aircraft_international_delhi = LinearRegression()
alg_oct_aircraft_international_delhi.fit(X_oct,Y_oct_aircraft_international_delhi)

Y_oct_aircraft_domestic_delhi = oct_aircraft_delhi["domestic"]
alg_oct_aircraft_domestic_delhi = LinearRegression()
alg_oct_aircraft_domestic_delhi.fit(X_oct,Y_oct_aircraft_domestic_delhi)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
predictions = alg_oct_aircraft_international_delhi.predict([[2019],[2020], [2021]])
print("Prediction for 2019 -" , end = " ")
print(int(predictions[0]))
print("Prediction for 2020 -" , end = " ")
print(int(predictions[1]))
print("Prediction for 2021 -" , end = " ")
print(int(predictions[2]))
# Out:
# Prediction for 2019 - 9585
# Prediction for 2020 - 9976
# Prediction for 2021 - 10367

# %%
plt.scatter(X_oct,Y_oct_aircraft_international_delhi)

plt.scatter([2019,2020,2021], predictions, marker = "^")


plt.title("Delhi International")
plt.ylabel("Aircrafts")
plt.xlabel("Year")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
predictions = alg_oct_aircraft_domestic_delhi.predict([[2019],[2020], [2021]])
print("Prediction for 2019 -" , end = " ")
print(int(predictions[0]))
print("Prediction for 2020 -" , end = " ")
print(int(predictions[1]))
print("Prediction for 2021 -" , end = " ")
print(int(predictions[2]))
# Out:
# Prediction for 2019 - 27872
# Prediction for 2020 - 29355
# Prediction for 2021 - 30838

# %%
plt.scatter(X_oct,Y_oct_aircraft_domestic_delhi)

plt.scatter([2019,2020,2021], predictions, marker = "^")


plt.title("Delhi Domestic")
plt.ylabel("Aircrafts")
plt.xlabel("Year")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %% [markdown]
# ## Freight All India International and Domestic

# %%
oct_freight = pd.read_csv("/Users/kushalgupta/Downloads/Main/10. Oct/Comma Delimited/Freight/All India.csv")
oct_freight = oct_freight.iloc[0:10,:]
oct_freight.columns = ["year","international","domestic","total"]
X_oct = oct_freight["year"].values.reshape(-1,1)
Y_oct_freight_international = oct_freight["international"]
alg_oct_freight_international = LinearRegression()
alg_oct_freight_international.fit(X_oct,Y_oct_freight_international)

Y_oct_freight_domestic = oct_aircraft["domestic"]
alg_oct_freight_domestic = LinearRegression()
alg_oct_freight_domestic.fit(X_oct,Y_oct_freight_domestic)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
predictions = alg_oct_freight_international.predict([[2019],[2020], [2021]])
print("Prediction for 2019 -" , end = " ")
print(int(predictions[0]))
print("Prediction for 2020 -" , end = " ")
print(int(predictions[1]))
print("Prediction for 2021 -" , end = " ")
print(int(predictions[2]))
# Out:
# Prediction for 2019 - 175564
# Prediction for 2020 - 182707
# Prediction for 2021 - 189850

# %%
plt.scatter(X_oct,Y_oct_freight_international)

plt.scatter([2019,2020,2021], predictions, marker = "^")


plt.title("All India International")
plt.ylabel("Freights")
plt.xlabel("Year")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
predictions = alg_oct_freight_domestic.predict([[2019],[2020], [2021]])
print("Prediction for 2019 -" , end = " ")
print(int(predictions[0]))
print("Prediction for 2020 -" , end = " ")
print(int(predictions[1]))
print("Prediction for 2021 -" , end = " ")
print(int(predictions[2]))
# Out:
# Prediction for 2019 - 162860
# Prediction for 2020 - 171162
# Prediction for 2021 - 179465

# %%
plt.scatter(X_oct,Y_oct_freight_domestic)

plt.scatter([2019,2020,2021], predictions, marker = "^")


plt.title("All India Domestic")
plt.ylabel("Freights")
plt.xlabel("Year")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %% [markdown]
# ## Freight Delhi International and Domestic

# %%
oct_freight_delhi = pd.read_csv("/Users/kushalgupta/Downloads/Main/10. Oct/Comma Delimited/Freight/Delhi.csv")
oct_freight_delhi = oct_freight_delhi.iloc[0:10,:]
oct_freight_delhi.columns = ["year","international","domestic","total"]
X_oct = oct_freight_delhi["year"].values.reshape(-1,1)
Y_oct_freight_international_delhi = oct_freight_delhi["international"]
alg_oct_freight_international_delhi = LinearRegression()
alg_oct_freight_international_delhi.fit(X_oct,Y_oct_freight_international_delhi)

Y_oct_freight_domestic_delhi = oct_freight_delhi["domestic"]
alg_oct_freight_domestic_delhi = LinearRegression()
alg_oct_freight_domestic_delhi.fit(X_oct,Y_oct_freight_domestic_delhi)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
predictions = alg_oct_freight_international_delhi.predict([[2019],[2020], [2021]])
print("Prediction for 2019 -" , end = " ")
print(int(predictions[0]))
print("Prediction for 2020 -" , end = " ")
print(int(predictions[1]))
print("Prediction for 2021 -" , end = " ")
print(int(predictions[2]))
# Out:
# Prediction for 2019 - 54995
# Prediction for 2020 - 57990
# Prediction for 2021 - 60986

# %%
plt.scatter(X_oct,Y_oct_freight_international_delhi)

plt.scatter([2019,2020,2021], predictions, marker = "^")



plt.title("Delhi International")
plt.ylabel("Freights")
plt.xlabel("Year")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
predictions = alg_oct_freight_domestic_delhi.predict([[2019],[2020], [2021]])
print("Prediction for 2019 -" , end = " ")
print(int(predictions[0]))
print("Prediction for 2020 -" , end = " ")
print(int(predictions[1]))
print("Prediction for 2021 -" , end = " ")
print(int(predictions[2]))
# Out:
# Prediction for 2019 - 33671
# Prediction for 2020 - 35646
# Prediction for 2021 - 37621

# %%
plt.scatter(X_oct,Y_oct_freight_domestic_delhi)

plt.scatter([2019,2020,2021], predictions, marker = "^")


plt.title("Delhi Domestic")
plt.ylabel("Freights")
plt.xlabel("Year")
# Out:
# Text(0.5,0,'Year')

# %% [markdown]
# ## Passengers All India International and Domestic

# %%
oct_passengers = pd.read_csv("/Users/kushalgupta/Downloads/Main/10. Oct/Comma Delimited/Passengers/All India.csv")
oct_passengers = oct_passengers.iloc[0:10,:]
oct_passengers.columns = ["year","international","domestic","total"]
X_oct = oct_passengers["year"].values.reshape(-1,1)
Y_oct_passengers_international = oct_passengers["international"]
alg_oct_passengers_international = LinearRegression()
alg_oct_passengers_international.fit(X_oct,Y_oct_passengers_international)

Y_oct_passengers_domestic = oct_passengers["domestic"]
alg_oct_passengers_domestic = LinearRegression()
alg_oct_passengers_domestic.fit(X_oct,Y_oct_passengers_domestic)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
predictions = alg_oct_passengers_international.predict([[2019],[2020], [2021]])
print("Prediction for 2019 -" , end = " ")
print(int(predictions[0]))
print("Prediction for 2020 -" , end = " ")
print(int(predictions[1]))
print("Prediction for 2021 -" , end = " ")
print(int(predictions[2]))
# Out:
# Prediction for 2019 - 5587856
# Prediction for 2020 - 5872485
# Prediction for 2021 - 6157113

# %%
plt.scatter(X_oct,Y_oct_passengers_international)

plt.scatter([2019,2020,2021], predictions, marker = "^")


plt.title("All India International")
plt.ylabel("Passengers")
plt.xlabel("Year")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
predictions = alg_oct_passengers_domestic.predict([[2019],[2020], [2021]])
print("Prediction for 2019 -" , end = " ")
print(int(predictions[0]))
print("Prediction for 2020 -" , end = " ")
print(int(predictions[1]))
print("Prediction for 2021 -" , end = " ")
print(int(predictions[2]))
# Out:
# Prediction for 2019 - 20711454
# Prediction for 2020 - 22147412
# Prediction for 2021 - 23583370

# %%
plt.scatter(X_oct,Y_oct_passengers_domestic)
plt.scatter([2019,2020,2021], predictions, marker = "^")


plt.title("All India Domestic")
plt.ylabel("Passengers")
plt.xlabel("Year")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %% [markdown]
# ## passengers Delhi International and Domestic

# %%
oct_passengers_delhi = pd.read_csv("/Users/kushalgupta/Downloads/Main/10. Oct/Comma Delimited/Passengers/Delhi.csv")
oct_passengers_delhi = oct_passengers_delhi.iloc[0:10,:]
oct_passengers_delhi.columns = ["year","international","domestic","total"]
X_oct = oct_passengers_delhi["year"].values.reshape(-1,1)
Y_oct_passengers_international_delhi = oct_passengers_delhi["international"]
alg_oct_passengers_international_delhi = LinearRegression()
alg_oct_passengers_international_delhi.fit(X_oct,Y_oct_passengers_international_delhi)

Y_oct_passengers_domestic_delhi = oct_passengers_delhi["domestic"]
alg_oct_passengers_domestic_delhi = LinearRegression()
alg_oct_passengers_domestic_delhi.fit(X_oct,Y_oct_passengers_domestic_delhi)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
predictions = alg_oct_passengers_international_delhi.predict([[2019],[2020], [2021]])
print("Prediction for 2019 -" , end = " ")
print(int(predictions[0]))
print("Prediction for 2020 -" , end = " ")
print(int(predictions[1]))
print("Prediction for 2021 -" , end = " ")
print(int(predictions[2]))
# Out:
# Prediction for 2019 - 1530943
# Prediction for 2020 - 1612884
# Prediction for 2021 - 1694825

# %%
plt.scatter(X_oct,Y_oct_passengers_international_delhi)

plt.scatter([2019,2020,2021], predictions, marker = "^")


plt.title("Delhi International")
plt.ylabel("Passengers")
plt.xlabel("Year")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
predictions = alg_oct_passengers_domestic_delhi.predict([[2019],[2020], [2021]])
print("Prediction for 2019 -" , end = " ")
print(int(predictions[0]))
print("Prediction for 2020 -" , end = " ")
print(int(predictions[1]))
print("Prediction for 2021 -" , end = " ")
print(int(predictions[2]))
# Out:
# Prediction for 2019 - 4180625
# Prediction for 2020 - 4474835
# Prediction for 2021 - 4769045

# %%
plt.scatter(X_oct,Y_oct_passengers_domestic_delhi)

plt.scatter([2019,2020,2021], predictions, marker = "^")


plt.title("Delhi Domestic")
plt.ylabel("Passengers")
plt.xlabel("Year")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
def f10(yr):
    yr = int(yr)
    return "10/" + str(yr)

# %%
oct_aircraft["month"] = "oct" 
oct_aircraft["month_year"] = oct_aircraft.year.apply(f10)
oct_aircraft_delhi["month"] = "oct"
oct_aircraft_delhi["month_year"] = oct_aircraft_delhi.year.apply(f10)

oct_freight["month"] = "oct" 
oct_freight["month_year"] = oct_freight.year.apply(f10)
oct_freight_delhi["month"] = "oct"
oct_freight_delhi["month_year"] = oct_freight_delhi.year.apply(f10)


oct_passengers["month"] = "oct" 
oct_passengers["month_year"] = oct_passengers.year.apply(f10)
oct_passengers_delhi["month"] = "oct"
oct_passengers_delhi["month_year"] = oct_passengers_delhi.year.apply(f10)

# %%
aircraft_dfs = [all_india_aircraft,oct_aircraft]
all_india_aircraft = pd.concat(aircraft_dfs).reset_index(drop = True)
delhi_aircraft_dfs = [delhi_aircraft,oct_aircraft_delhi]
delhi_aircraft = pd.concat(delhi_aircraft_dfs).reset_index(drop = True)

freight_dfs = [all_india_freight,oct_freight]
all_india_freight = pd.concat(freight_dfs).reset_index(drop = True)
delhi_freight_dfs = [delhi_freight,oct_freight_delhi]
delhi_freight = pd.concat(delhi_freight_dfs).reset_index(drop = True)


passengers_dfs = [all_india_passengers,oct_passengers]
all_india_passengers = pd.concat(passengers_dfs).reset_index(drop = True)
delhi_passengers_dfs = [delhi_passengers,oct_passengers_delhi]
delhi_passengers = pd.concat(delhi_passengers_dfs).reset_index(drop = True)

# %% [markdown]
# # November

# %% [markdown]
# ## Aircraft All India International and Domestic

# %%
nov_aircraft = pd.read_csv("/Users/kushalgupta/Downloads/Main/11. Nov/Comma Delimited/Aircraft/All India.csv")
nov_aircraft = nov_aircraft.iloc[0:10,:]
nov_aircraft.columns = ["year","international","domestic","total"]
X_nov = nov_aircraft["year"].values.reshape(-1,1)
Y_nov_aircraft_international = nov_aircraft["international"]
alg_nov_aircraft_international = LinearRegression()
alg_nov_aircraft_international.fit(X_nov,Y_nov_aircraft_international)

Y_nov_aircraft_domestic = nov_aircraft["domestic"]
alg_nov_aircraft_domestic = LinearRegression()
alg_nov_aircraft_domestic.fit(X_nov,Y_nov_aircraft_domestic)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
predictions = alg_nov_aircraft_international.predict([[2019],[2020], [2021]])
print("Prediction for 2019 -" , end = " ")
print(int(predictions[0]))
print("Prediction for 2020 -" , end = " ")
print(int(predictions[1]))
print("Prediction for 2021 -" , end = " ")
print(int(predictions[2]))
# Out:
# Prediction for 2019 - 37792
# Prediction for 2020 - 39180
# Prediction for 2021 - 40569

# %%
plt.scatter(X_nov,Y_nov_aircraft_international)

plt.scatter([2019,2020,2021], predictions, marker = "^")


plt.title("All India International")
plt.ylabel("Aircrafts")
plt.xlabel("Year")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
predictions = alg_nov_aircraft_domestic.predict([[2019],[2020], [2021]])
print("Prediction for 2019 -" , end = " ")
print(int(predictions[0]))
print("Prediction for 2020 -" , end = " ")
print(int(predictions[1]))
print("Prediction for 2021 -" , end = " ")
print(int(predictions[2]))
# Out:
# Prediction for 2019 - 157452
# Prediction for 2020 - 165222
# Prediction for 2021 - 172992

# %%
plt.scatter(X_nov,Y_nov_aircraft_domestic)

plt.scatter([2019,2020,2021], predictions, marker = "^")


plt.title("All India Domestic")
plt.ylabel("Aircrafts")
plt.xlabel("Year")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %% [markdown]
# ## Aircraft Delhi International and Domestic

# %%
nov_aircraft_delhi = pd.read_csv("/Users/kushalgupta/Downloads/Main/11. Nov/Comma Delimited/Aircraft/Delhi.csv")
nov_aircraft_delhi = nov_aircraft_delhi.iloc[0:8,:]
nov_aircraft_delhi.columns = ["year","international","domestic","total"]
X_nov = nov_aircraft_delhi["year"].values.reshape(-1,1)
Y_nov_aircraft_international_delhi = nov_aircraft_delhi["international"]
alg_nov_aircraft_international_delhi = LinearRegression()
alg_nov_aircraft_international_delhi.fit(X_nov,Y_nov_aircraft_international_delhi)

Y_nov_aircraft_domestic_delhi = nov_aircraft_delhi["domestic"]
alg_nov_aircraft_domestic_delhi = LinearRegression()
alg_nov_aircraft_domestic_delhi.fit(X_nov,Y_nov_aircraft_domestic_delhi)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
predictions = alg_nov_aircraft_international_delhi.predict([[2019],[2020], [2021]])
print("Prediction for 2019 -" , end = " ")
print(int(predictions[0]))
print("Prediction for 2020 -" , end = " ")
print(int(predictions[1]))
print("Prediction for 2021 -" , end = " ")
print(int(predictions[2]))
# Out:
# Prediction for 2019 - 9160
# Prediction for 2020 - 9463
# Prediction for 2021 - 9766

# %%
plt.scatter(X_nov,Y_nov_aircraft_international_delhi)

plt.scatter([2019,2020,2021], predictions, marker = "^")


plt.title("Delhi International")
plt.ylabel("Aircrafts")
plt.xlabel("Year")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
predictions = alg_nov_aircraft_domestic_delhi.predict([[2019],[2020], [2021]])
print("Prediction for 2019 -" , end = " ")
print(int(predictions[0]))
print("Prediction for 2020 -" , end = " ")
print(int(predictions[1]))
print("Prediction for 2021 -" , end = " ")
print(int(predictions[2]))
# Out:
# Prediction for 2019 - 28831
# Prediction for 2020 - 30486
# Prediction for 2021 - 32141

# %%
plt.scatter(X_nov,Y_nov_aircraft_domestic_delhi)

plt.scatter([2019,2020,2021], predictions, marker = "^")


plt.title("Delhi Domestic")
plt.ylabel("Aircrafts")
plt.xlabel("Year")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %% [markdown]
# ## Freight All India International and Domestic

# %%
nov_freight = pd.read_csv("/Users/kushalgupta/Downloads/Main/11. Nov/Comma Delimited/Freight/All India.csv")
nov_freight = nov_freight.iloc[0:10,:]
nov_freight.columns = ["year","international","domestic","total"]
X_nov = nov_freight["year"].values.reshape(-1,1)
Y_nov_freight_international = nov_freight["international"]
alg_nov_freight_international = LinearRegression()
alg_nov_freight_international.fit(X_nov,Y_nov_freight_international)

Y_nov_freight_domestic = nov_aircraft["domestic"]
alg_nov_freight_domestic = LinearRegression()
alg_nov_freight_domestic.fit(X_nov,Y_nov_freight_domestic)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
predictions = alg_nov_freight_international.predict([[2019],[2020], [2021]])
print("Prediction for 2019 -" , end = " ")
print(int(predictions[0]))
print("Prediction for 2020 -" , end = " ")
print(int(predictions[1]))
print("Prediction for 2021 -" , end = " ")
print(int(predictions[2]))
# Out:
# Prediction for 2019 - 172465
# Prediction for 2020 - 179839
# Prediction for 2021 - 187213

# %%
plt.scatter(X_nov,Y_nov_freight_international)

plt.scatter([2019,2020,2021], predictions, marker = "^")


plt.title("All India International")
plt.ylabel("Freights")
plt.xlabel("Year")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
predictions = alg_nov_freight_domestic.predict([[2019],[2020], [2021]])
print("Prediction for 2019 -" , end = " ")
print(int(predictions[0]))
print("Prediction for 2020 -" , end = " ")
print(int(predictions[1]))
print("Prediction for 2021 -" , end = " ")
print(int(predictions[2]))
# Out:
# Prediction for 2019 - 157452
# Prediction for 2020 - 165222
# Prediction for 2021 - 172992

# %%
plt.scatter(X_nov,Y_nov_freight_domestic)

plt.scatter([2019,2020,2021], predictions, marker = "^")


plt.title("All India Domestic")
plt.ylabel("Freights")
plt.xlabel("Year")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %% [markdown]
# ## Freight Delhi International and Domestic

# %%
nov_freight_delhi = pd.read_csv("/Users/kushalgupta/Downloads/Main/11. Nov/Comma Delimited/Freight/Delhi.csv")
nov_freight_delhi = nov_freight_delhi.iloc[0:8,:]
nov_freight_delhi.columns = ["year","international","domestic","total"]
X_nov = nov_freight_delhi["year"].values.reshape(-1,1)
Y_nov_freight_international_delhi = nov_freight_delhi["international"]
alg_nov_freight_international_delhi = LinearRegression()
alg_nov_freight_international_delhi.fit(X_nov,Y_nov_freight_international_delhi)

Y_nov_freight_domestic_delhi = nov_freight_delhi["domestic"]
alg_nov_freight_domestic_delhi = LinearRegression()
alg_nov_freight_domestic_delhi.fit(X_nov,Y_nov_freight_domestic_delhi)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
predictions = alg_nov_freight_international_delhi.predict([[2019],[2020], [2021]])
print("Prediction for 2019 -" , end = " ")
print(int(predictions[0]))
print("Prediction for 2020 -" , end = " ")
print(int(predictions[1]))
print("Prediction for 2021 -" , end = " ")
print(int(predictions[2]))
# Out:
# Prediction for 2019 - 55153
# Prediction for 2020 - 58618
# Prediction for 2021 - 62082

# %%
plt.scatter(X_nov,Y_nov_freight_international_delhi)

plt.scatter([2019,2020,2021], predictions, marker = "^")


plt.title("Delhi International")
plt.ylabel("Freights")
plt.xlabel("Year")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
predictions = alg_nov_freight_domestic_delhi.predict([[2019],[2020], [2021]])
print("Prediction for 2019 -" , end = " ")
print(int(predictions[0]))
print("Prediction for 2020 -" , end = " ")
print(int(predictions[1]))
print("Prediction for 2021 -" , end = " ")
print(int(predictions[2]))
# Out:
# Prediction for 2019 - 29022
# Prediction for 2020 - 30547
# Prediction for 2021 - 32072

# %%
plt.scatter(X_nov,Y_nov_freight_domestic_delhi)

plt.scatter([2019,2020,2021], predictions, marker = "^")


plt.title("Delhi Domestic")
plt.ylabel("Freights")
plt.xlabel("Year")
# Out:
# Text(0.5,0,'Year')

# %% [markdown]
# ## Passengers All India International and Domestic

# %%
nov_passengers = pd.read_csv("/Users/kushalgupta/Downloads/Main/11. Nov/Comma Delimited/Passengers/All India.csv")
nov_passengers = nov_passengers.iloc[0:10,:]
nov_passengers.columns = ["year","international","domestic","total"]
X_nov = nov_passengers["year"].values.reshape(-1,1)
Y_nov_passengers_international = nov_passengers["international"]
alg_nov_passengers_international = LinearRegression()
alg_nov_passengers_international.fit(X_nov,Y_nov_passengers_international)

Y_nov_passengers_domestic = nov_passengers["domestic"]
alg_nov_passengers_domestic = LinearRegression()
alg_nov_passengers_domestic.fit(X_nov,Y_nov_passengers_domestic)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
predictions = alg_nov_passengers_international.predict([[2019],[2020], [2021]])
print("Prediction for 2019 -" , end = " ")
print(int(predictions[0]))
print("Prediction for 2020 -" , end = " ")
print(int(predictions[1]))
print("Prediction for 2021 -" , end = " ")
print(int(predictions[2]))
# Out:
# Prediction for 2019 - 5767055
# Prediction for 2020 - 6053207
# Prediction for 2021 - 6339358

# %%
plt.scatter(X_nov,Y_nov_passengers_international)

plt.scatter([2019,2020,2021], predictions, marker = "^")


plt.title("All India International")
plt.ylabel("Passengers")
plt.xlabel("Year")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
predictions = alg_nov_passengers_domestic.predict([[2019],[2020], [2021]])
print("Prediction for 2019 -" , end = " ")
print(int(predictions[0]))
print("Prediction for 2020 -" , end = " ")
print(int(predictions[1]))
print("Prediction for 2021 -" , end = " ")
print(int(predictions[2]))
# Out:
# Prediction for 2019 - 21105678
# Prediction for 2020 - 22552707
# Prediction for 2021 - 23999735

# %%
plt.scatter(X_nov,Y_nov_passengers_domestic)

plt.scatter([2019,2020,2021], predictions, marker = "^")


plt.title("All India Domestic")
plt.ylabel("Passengers")
plt.xlabel("Year")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %% [markdown]
# ## passengers Delhi International and Domestic

# %%
nov_passengers_delhi = pd.read_csv("/Users/kushalgupta/Downloads/Main/11. Nov/Comma Delimited/Passengers/Delhi.csv")
nov_passengers_delhi = nov_passengers_delhi.iloc[0:8,:]
nov_passengers_delhi.columns = ["year","international","domestic","total"]
X_nov = nov_passengers_delhi["year"].values.reshape(-1,1)
Y_nov_passengers_international_delhi = nov_passengers_delhi["international"]
alg_nov_passengers_international_delhi = LinearRegression()
alg_nov_passengers_international_delhi.fit(X_nov,Y_nov_passengers_international_delhi)

Y_nov_passengers_domestic_delhi = nov_passengers_delhi["domestic"]
alg_nov_passengers_domestic_delhi = LinearRegression()
alg_nov_passengers_domestic_delhi.fit(X_nov,Y_nov_passengers_domestic_delhi)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
predictions = alg_nov_passengers_international_delhi.predict([[2019],[2020], [2021]])
print("Prediction for 2019 -" , end = " ")
print(int(predictions[0]))
print("Prediction for 2020 -" , end = " ")
print(int(predictions[1]))
print("Prediction for 2021 -" , end = " ")
print(int(predictions[2]))
# Out:
# Prediction for 2019 - 1620553
# Prediction for 2020 - 1708355
# Prediction for 2021 - 1796156

# %%
plt.scatter(X_nov,Y_nov_passengers_international_delhi)

plt.scatter([2019,2020,2021], predictions, marker = "^")


plt.title("Delhi International")
plt.ylabel("Passengers")
plt.xlabel("Year")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
predictions = alg_nov_passengers_domestic_delhi.predict([[2019],[2020], [2021]])
print("Prediction for 2019 -" , end = " ")
print(int(predictions[0]))
print("Prediction for 2020 -" , end = " ")
print(int(predictions[1]))
print("Prediction for 2021 -" , end = " ")
print(int(predictions[2]))
# Out:
# Prediction for 2019 - 4342764
# Prediction for 2020 - 4663111
# Prediction for 2021 - 4983459

# %%
plt.scatter(X_nov,Y_nov_passengers_domestic_delhi)

plt.scatter([2019,2020,2021], predictions, marker = "^")


plt.title("Delhi Domestic")
plt.ylabel("Passengers")
plt.xlabel("Year")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
def f11(yr):
    yr = int(yr)
    return "11/" + str(yr)

# %%
nov_aircraft["month"] = "nov" 
nov_aircraft["month_year"] = nov_aircraft.year.apply(f11)
nov_aircraft_delhi["month"] = "nov"
nov_aircraft_delhi["month_year"] = nov_aircraft_delhi.year.apply(f11)

nov_freight["month"] = "nov" 
nov_freight["month_year"] = nov_freight.year.apply(f11)
nov_freight_delhi["month"] = "nov"
nov_freight_delhi["month_year"] = nov_freight_delhi.year.apply(f11)


nov_passengers["month"] = "nov" 
nov_passengers["month_year"] = nov_passengers.year.apply(f11)
nov_passengers_delhi["month"] = "nov"
nov_passengers_delhi["month_year"] = nov_passengers_delhi.year.apply(f11)

# %%
aircraft_dfs = [all_india_aircraft,nov_aircraft]
all_india_aircraft = pd.concat(aircraft_dfs).reset_index(drop = True)
delhi_aircraft_dfs = [delhi_aircraft,nov_aircraft_delhi]
delhi_aircraft = pd.concat(delhi_aircraft_dfs).reset_index(drop = True)

freight_dfs = [all_india_freight,nov_freight]
all_india_freight = pd.concat(freight_dfs).reset_index(drop = True)
delhi_freight_dfs = [delhi_freight,nov_freight_delhi]
delhi_freight = pd.concat(delhi_freight_dfs).reset_index(drop = True)


passengers_dfs = [all_india_passengers,nov_passengers]
all_india_passengers = pd.concat(passengers_dfs).reset_index(drop = True)
delhi_passengers_dfs = [delhi_passengers,nov_passengers_delhi]
delhi_passengers = pd.concat(delhi_passengers_dfs).reset_index(drop = True)

# %% [markdown]
# # Dec

# %% [markdown]
# ## Aircraft All India International and Domestic

# %%
dec_aircraft = pd.read_csv("/Users/kushalgupta/Downloads/Main/12. Dec/Comma Delimited/Aircraft/All India.csv")
dec_aircraft = dec_aircraft.iloc[0:10,:]
dec_aircraft.columns = ["year","international","domestic","total"]
X_dec = dec_aircraft["year"].values.reshape(-1,1)
Y_dec_aircraft_international = dec_aircraft["international"]
alg_dec_aircraft_international = LinearRegression()
alg_dec_aircraft_international.fit(X_dec,Y_dec_aircraft_international)

Y_dec_aircraft_domestic = dec_aircraft["domestic"]
alg_dec_aircraft_domestic = LinearRegression()
alg_dec_aircraft_domestic.fit(X_dec,Y_dec_aircraft_domestic)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
predictions = alg_dec_aircraft_international.predict([[2019],[2020], [2021]])
print("Prediction for 2019 -" , end = " ")
print(int(predictions[0]))
print("Prediction for 2020 -" , end = " ")
print(int(predictions[1]))
print("Prediction for 2021 -" , end = " ")
print(int(predictions[2]))
# Out:
# Prediction for 2019 - 39704
# Prediction for 2020 - 41254
# Prediction for 2021 - 42804

# %%
plt.scatter(X_dec,Y_dec_aircraft_international)

plt.scatter([2019,2020,2021], predictions, marker = "^")


plt.title("All India International")
plt.ylabel("Aircrafts")
plt.xlabel("Year")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
predictions = alg_dec_aircraft_domestic.predict([[2019],[2020], [2021]])
print("Prediction for 2019 -" , end = " ")
print(int(predictions[0]))
print("Prediction for 2020 -" , end = " ")
print(int(predictions[1]))
print("Prediction for 2021 -" , end = " ")
print(int(predictions[2]))
# Out:
# Prediction for 2019 - 161684
# Prediction for 2020 - 169571
# Prediction for 2021 - 177458

# %%
plt.scatter(X_dec,Y_dec_aircraft_domestic)

plt.scatter([2019,2020,2021], predictions, marker = "^")


plt.title("All India Domestic")
plt.ylabel("Aircrafts")
plt.xlabel("Year")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %% [markdown]
# ## Aircraft Delhi International and Domestic

# %%
dec_aircraft_delhi = pd.read_csv("/Users/kushalgupta/Downloads/Main/12. Dec/Comma Delimited/Aircraft/Delhi.csv")
dec_aircraft_delhi = dec_aircraft_delhi.iloc[0:8,:]
dec_aircraft_delhi.columns = ["year","international","domestic","total"]
X_dec = dec_aircraft_delhi["year"].values.reshape(-1,1)
Y_dec_aircraft_international_delhi = dec_aircraft_delhi["international"]
alg_dec_aircraft_international_delhi = LinearRegression()
alg_dec_aircraft_international_delhi.fit(X_dec,Y_dec_aircraft_international_delhi)

Y_dec_aircraft_domestic_delhi = dec_aircraft_delhi["domestic"]
alg_dec_aircraft_domestic_delhi = LinearRegression()
alg_dec_aircraft_domestic_delhi.fit(X_dec,Y_dec_aircraft_domestic_delhi)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
predictions = alg_dec_aircraft_international_delhi.predict([[2019],[2020], [2021]])
print("Prediction for 2019 -" , end = " ")
print(int(predictions[0]))
print("Prediction for 2020 -" , end = " ")
print(int(predictions[1]))
print("Prediction for 2021 -" , end = " ")
print(int(predictions[2]))
# Out:
# Prediction for 2019 - 9706
# Prediction for 2020 - 10075
# Prediction for 2021 - 10444

# %%
plt.scatter(X_dec,Y_dec_aircraft_international_delhi)

plt.scatter([2019,2020,2021], predictions, marker = "^")


plt.title("Delhi International")
plt.ylabel("Aircrafts")
plt.xlabel("Year")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
predictions = alg_dec_aircraft_domestic_delhi.predict([[2019],[2020], [2021]])
print("Prediction for 2019 -" , end = " ")
print(int(predictions[0]))
print("Prediction for 2020 -" , end = " ")
print(int(predictions[1]))
print("Prediction for 2021 -" , end = " ")
print(int(predictions[2]))
# Out:
# Prediction for 2019 - 29037
# Prediction for 2020 - 30647
# Prediction for 2021 - 32257

# %%
plt.scatter(X_dec,Y_dec_aircraft_domestic_delhi)

plt.scatter([2019,2020,2021], predictions, marker = "^")


plt.title("Delhi Domestic")
plt.ylabel("Aircrafts")
plt.xlabel("Year")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %% [markdown]
# ## Freight All India International and Domestic

# %%
dec_freight = pd.read_csv("/Users/kushalgupta/Downloads/Main/12. Dec/Comma Delimited/Freight/All India.csv")
dec_freight = dec_freight.iloc[0:10,:]
dec_freight.columns = ["year","international","domestic","total"]
X_dec = dec_freight["year"].values.reshape(-1,1)
Y_dec_freight_international = dec_freight["international"]
alg_dec_freight_international = LinearRegression()
alg_dec_freight_international.fit(X_dec,Y_dec_freight_international)

Y_dec_freight_domestic = dec_aircraft["domestic"]
alg_dec_freight_domestic = LinearRegression()
alg_dec_freight_domestic.fit(X_dec,Y_dec_freight_domestic)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
predictions = alg_dec_freight_international.predict([[2019],[2020], [2021]])
print("Prediction for 2019 -" , end = " ")
print(int(predictions[0]))
print("Prediction for 2020 -" , end = " ")
print(int(predictions[1]))
print("Prediction for 2021 -" , end = " ")
print(int(predictions[2]))
# Out:
# Prediction for 2019 - 173328
# Prediction for 2020 - 180344
# Prediction for 2021 - 187359

# %%
plt.scatter(X_dec,Y_dec_freight_international)

plt.scatter([2019,2020,2021], predictions, marker = "^")


plt.title("All India International")
plt.ylabel("Freights")
plt.xlabel("Year")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
predictions = alg_dec_freight_domestic.predict([[2019],[2020], [2021]])
print("Prediction for 2019 -" , end = " ")
print(int(predictions[0]))
print("Prediction for 2020 -" , end = " ")
print(int(predictions[1]))
print("Prediction for 2021 -" , end = " ")
print(int(predictions[2]))
# Out:
# Prediction for 2019 - 161684
# Prediction for 2020 - 169571
# Prediction for 2021 - 177458

# %%
plt.scatter(X_dec,Y_dec_freight_domestic)

plt.scatter([2019,2020,2021], predictions, marker = "^")


plt.title("All India Domestic")
plt.ylabel("Freights")
plt.xlabel("Year")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %% [markdown]
# ## Freight Delhi International and Domestic

# %%
dec_freight_delhi = pd.read_csv("/Users/kushalgupta/Downloads/Main/12. Dec/Comma Delimited/Freight/Delhi.csv")
dec_freight_delhi = dec_freight_delhi.iloc[0:8,:]
dec_freight_delhi.columns = ["year","international","domestic","total"]
X_dec = dec_freight_delhi["year"].values.reshape(-1,1)
Y_dec_freight_international_delhi = dec_freight_delhi["international"]
alg_dec_freight_international_delhi = LinearRegression()
alg_dec_freight_international_delhi.fit(X_dec,Y_dec_freight_international_delhi)

Y_dec_freight_domestic_delhi = dec_freight_delhi["domestic"]
alg_dec_freight_domestic_delhi = LinearRegression()
alg_dec_freight_domestic_delhi.fit(X_dec,Y_dec_freight_domestic_delhi)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
predictions = alg_dec_freight_international_delhi.predict([[2019],[2020], [2021]])
print("Prediction for 2019 -" , end = " ")
print(int(predictions[0]))
print("Prediction for 2020 -" , end = " ")
print(int(predictions[1]))
print("Prediction for 2021 -" , end = " ")
print(int(predictions[2]))
# Out:
# Prediction for 2019 - 55943
# Prediction for 2020 - 59375
# Prediction for 2021 - 62807

# %%
plt.scatter(X_dec,Y_dec_freight_international_delhi)

plt.scatter([2019,2020,2021], predictions, marker = "^")


plt.title("Delhi International")
plt.ylabel("Freights")
plt.xlabel("Year")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
predictions = alg_dec_freight_domestic_delhi.predict([[2019],[2020], [2021]])
print("Prediction for 2019 -" , end = " ")
print(int(predictions[0]))
print("Prediction for 2020 -" , end = " ")
print(int(predictions[1]))
print("Prediction for 2021 -" , end = " ")
print(int(predictions[2]))
# Out:
# Prediction for 2019 - 29978
# Prediction for 2020 - 31498
# Prediction for 2021 - 33018

# %%
plt.scatter(X_dec,Y_dec_freight_domestic_delhi)

plt.scatter([2019,2020,2021], predictions, marker = "^")


plt.title("Delhi Domestic")
plt.ylabel("Freights")
plt.xlabel("Year")
# Out:
# Text(0.5,0,'Year')

# %% [markdown]
# ## Passengers All India International and Domestic

# %%
dec_passengers = pd.read_csv("/Users/kushalgupta/Downloads/Main/12. Dec/Comma Delimited/Passengers/All India.csv")
dec_passengers = dec_passengers.iloc[0:10,:]
dec_passengers.columns = ["year","international","domestic","total"]
X_dec = dec_passengers["year"].values.reshape(-1,1)
Y_dec_passengers_international = dec_passengers["international"]
alg_dec_passengers_international = LinearRegression()
alg_dec_passengers_international.fit(X_dec,Y_dec_passengers_international)

Y_dec_passengers_domestic = dec_passengers["domestic"]
alg_dec_passengers_domestic = LinearRegression()
alg_dec_passengers_domestic.fit(X_dec,Y_dec_passengers_domestic)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
predictions = alg_dec_passengers_international.predict([[2019],[2020], [2021]])
print("Prediction for 2019 -" , end = " ")
print(int(predictions[0]))
print("Prediction for 2020 -" , end = " ")
print(int(predictions[1]))
print("Prediction for 2021 -" , end = " ")
print(int(predictions[2]))
# Out:
# Prediction for 2019 - 6501935
# Prediction for 2020 - 6838621
# Prediction for 2021 - 7175307

# %%
plt.scatter(X_dec,Y_dec_passengers_international)

plt.scatter([2019,2020,2021], predictions, marker = "^")


plt.title("All India International")
plt.ylabel("Passengers")
plt.xlabel("Year")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
predictions = alg_dec_passengers_domestic.predict([[2019],[2020], [2021]])
print("Prediction for 2019 -" , end = " ")
print(int(predictions[0]))
print("Prediction for 2020 -" , end = " ")
print(int(predictions[1]))
print("Prediction for 2021 -" , end = " ")
print(int(predictions[2]))
# Out:
# Prediction for 2019 - 22383970
# Prediction for 2020 - 23886033
# Prediction for 2021 - 25388096

# %%
plt.scatter(X_dec,Y_dec_passengers_domestic)

plt.scatter([2019,2020,2021], predictions, marker = "^")


plt.title("All India Domestic")
plt.ylabel("Passengers")
plt.xlabel("Year")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %% [markdown]
# ## passengers Delhi International and Domestic

# %%
dec_passengers_delhi = pd.read_csv("/Users/kushalgupta/Downloads/Main/12. Dec/Comma Delimited/Passengers/Delhi.csv")
dec_passengers_delhi = dec_passengers_delhi.iloc[0:8,:]
dec_passengers_delhi.columns = ["year","international","domestic","total"]
X_dec = dec_passengers_delhi["year"].values.reshape(-1,1)
Y_dec_passengers_international_delhi = dec_passengers_delhi["international"]
alg_dec_passengers_international_delhi = LinearRegression()
alg_dec_passengers_international_delhi.fit(X_dec,Y_dec_passengers_international_delhi)

Y_dec_passengers_domestic_delhi = dec_passengers_delhi["domestic"]
alg_dec_passengers_domestic_delhi = LinearRegression()
alg_dec_passengers_domestic_delhi.fit(X_dec,Y_dec_passengers_domestic_delhi)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
predictions = alg_dec_passengers_international_delhi.predict([[2019],[2020], [2021]])
print("Prediction for 2019 -" , end = " ")
print(int(predictions[0]))
print("Prediction for 2020 -" , end = " ")
print(int(predictions[1]))
print("Prediction for 2021 -" , end = " ")
print(int(predictions[2]))
# Out:
# Prediction for 2019 - 1745832
# Prediction for 2020 - 1842726
# Prediction for 2021 - 1939621

# %%
plt.scatter(X_dec,Y_dec_passengers_international_delhi)

plt.scatter([2019,2020,2021], predictions, marker = "^")


plt.title("Delhi International")
plt.ylabel("Passengers")
plt.xlabel("Year")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
predictions = alg_dec_passengers_domestic_delhi.predict([[2019],[2020], [2021]])
print("Prediction for 2019 -" , end = " ")
print(int(predictions[0]))
print("Prediction for 2020 -" , end = " ")
print(int(predictions[1]))
print("Prediction for 2021 -" , end = " ")
print(int(predictions[2]))
# Out:
# Prediction for 2019 - 4589771
# Prediction for 2020 - 4929877
# Prediction for 2021 - 5269983

# %%
plt.scatter(X_dec,Y_dec_passengers_domestic_delhi)

plt.scatter([2019,2020,2021], predictions, marker = "^")


plt.title("Delhi Domestic")
plt.ylabel("Passengers")
plt.xlabel("Year")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
def f12(yr):
    yr = int(yr)
    return "12/" + str(yr)

# %%
dec_aircraft["month"] = "dec" 
dec_aircraft["month_year"] = dec_aircraft.year.apply(f12)
dec_aircraft_delhi["month"] = "dec"
dec_aircraft_delhi["month_year"] = dec_aircraft_delhi.year.apply(f12)

dec_freight["month"] = "dec" 
dec_freight["month_year"] = dec_freight.year.apply(f12)
dec_freight_delhi["month"] = "dec"
dec_freight_delhi["month_year"] = dec_freight_delhi.year.apply(f12)


dec_passengers["month"] = "dec" 
dec_passengers["month_year"] = dec_passengers.year.apply(f12)
dec_passengers_delhi["month"] = "dec"
dec_passengers_delhi["month_year"] = dec_passengers_delhi.year.apply(f12)

# %%
aircraft_dfs = [all_india_aircraft,dec_aircraft]
all_india_aircraft = pd.concat(aircraft_dfs).reset_index(drop = True)
delhi_aircraft_dfs = [delhi_aircraft,dec_aircraft_delhi]
delhi_aircraft = pd.concat(delhi_aircraft_dfs).reset_index(drop = True)

freight_dfs = [all_india_freight,dec_freight]
all_india_freight = pd.concat(freight_dfs).reset_index(drop = True)
delhi_freight_dfs = [delhi_freight,dec_freight_delhi]
delhi_freight = pd.concat(delhi_freight_dfs).reset_index(drop = True)


passengers_dfs = [all_india_passengers,dec_passengers]
all_india_passengers = pd.concat(passengers_dfs).reset_index(drop = True)
delhi_passengers_dfs = [delhi_passengers,dec_passengers_delhi]
delhi_passengers = pd.concat(delhi_passengers_dfs).reset_index(drop = True)
